# %% [markdown]
# ### 1.概要
# 内容主要涉及读取数据和保存数据、数据详情信息、数据处理、数据切片、筛选、排序、分组、统计、表格样式等几部分内容

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2.读取数据&保存数据

# %% [markdown]
# #### 读取csv，编码‘utf-8’

# %%
pd.read_csv('test1.csv', encoding='utf-8')
# Out:
#     姓名   年龄   身高
# 0   张三   24  167
# 1   李四   25  180
# 2   王五   28  176
# 3   赵六   24  167
# 4   周武   66  180
# 5   张叶   28  176
# 6   张器   24  167
# 7   李咯   25  180
# 8   王根   28  176
# 9   张灯   24  167
# 10  李放   25  180
# 11  王润   35  176

# %% [markdown]
# #### 读取前几行

# %%
csv_data = pd.read_csv('test1.csv')
pd.read_csv('test1.csv', encoding='utf-8', nrows = 3)
# Out:
#    姓名   年龄   身高
# 0  张三   24  167
# 1  李四   25  180
# 2  王五   28  176

# %% [markdown]
# #### 第一列作为行索引,忽略列索引

# %%
# 让第一列作索引 让第一行作数据不作标题
pd.read_csv('test1.csv', encoding = 'utf-8', index_col = 0, header = None)
# Out:
#       1     2
# 0
# 姓名   年龄    身高
# 张三   24   167
# 李四   25   180
# 王五   28   176
# 赵六   24   167
# 周武   66   180
# 张叶   28   176
# 张器   24   167
# 李咯   25   180
# 王根   28   176
# 张灯   24   167
# 李放   25   180
# 王润   35   176

# %% [markdown]
# #### 读取时忽略指定行

# %%
# 忽略一二两行和最后两行
pd.read_csv('test1.csv', skiprows = [1, 2], skipfooter = 2, engine = 'python')
# Out:
#    姓名   年龄   身高
# 0  王五   28  176
# 1  赵六   24  167
# 2  周武   66  180
# 3  张叶   28  176
# 4  张器   24  167
# 5  李咯   25  180
# 6  王根   28  176
# 7  张灯   24  167

# %% [markdown]
# #### 从限定分隔符逗号的文件或文本中读取数据

# %%
df = pd.read_table('test1.csv', sep = ',')

# %% [markdown]
# #### 保存数据

# %%
#df.to_excel('test1.xlsx')#默认会带索引列
df.to_excel('test1.xlsx', index = False)

# %%
df.to_json('test1.json')

# %% [markdown]
# ### 3.查看数据信息

# %% [markdown]
# #### 查看前n行

# %%
df.head(3)
# Out:
#    姓名   年龄   身高
# 0  张三   24  167
# 1  李四   25  180
# 2  王五   28  176

# %% [markdown]
# #### 查看后n行

# %%
df.tail(3)
# Out:
#     姓名   年龄   身高
# 9   张灯   24  167
# 10  李放   25  180
# 11  王润   35  176

# %% [markdown]
# #### 查看行数和列数

# %%
df.shape#包含标题行
# Out:
# (12, 3)

# %% [markdown]
# #### 查看索引、数据类型和内存信息

# %%
df.columns #列索引
# Out:
# Index(['姓名', ' 年龄', ' 身高'], dtype='object')

# %%
df.index #行索引
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.info() #查看索引、数据类型和内存信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   姓名      12 non-null     object
#  1    年龄     12 non-null     int64
#  2    身高     12 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 416.0+ bytes

# %% [markdown]
# #### 查看数值型列的汇总统计

# %%
df.describe()
# Out:
#               年龄          身高
# count  12.000000   12.000000
# mean   29.666667  174.333333
# std    11.873066    5.678241
# min    24.000000  167.000000
# 25%    24.000000  167.000000
# 50%    25.000000  176.000000
# 75%    28.000000  180.000000
# max    66.000000  180.000000

# %% [markdown]
# #### 查看每一列的唯一值和计数

# %%
pd.read_json('test1.json').apply(pd.Series.value_counts)
# 第一列为唯一值是什么 后面有数字代表有几个
# Out:
#       姓名   年龄   身高
# 周武   1.0  NaN  NaN
# 张三   1.0  NaN  NaN
# 张叶   1.0  NaN  NaN
# 张器   1.0  NaN  NaN
# 张灯   1.0  NaN  NaN
# 李咯   1.0  NaN  NaN
# 李四   1.0  NaN  NaN
# 李放   1.0  NaN  NaN
# 王五   1.0  NaN  NaN
# 王根   1.0  NaN  NaN
# 王润   1.0  NaN  NaN
# 赵六   1.0  NaN  NaN
# 24   NaN  4.0  NaN
# 25   NaN  3.0  NaN
# 28   NaN  3.0  NaN
# 66   NaN  1.0  NaN
# 35   NaN  1.0  NaN
# 167  NaN  NaN  4.0
# 180  NaN  NaN  4.0
# 176  NaN  NaN  4.0

# %% [markdown]
# #### apply
# 参考 &gt; https://zhuanlan.zhihu.com/p/344835017
#
# 遍历DataFrame的元素（一行数据或者一列数据）
#
# dataframe.apply(function,axis)对一行或一列做出一些操作（axis=1遍历行，axis=0遍历列）

# %% [markdown]
# ### 4.数据处理

# %% [markdown]
# #### 重命名列名

# %%
df.columns = ['name', 'age', 'height']

# %% [markdown]
# #### 选择性更改列名

# %%
df.rename(columns = {'name' : '姓名', 'age' : '年龄'}, inplace = True)
df
# Out:
#     姓名  年龄  height
# 0   张三  24     167
# 1   李四  25     180
# 2   王五  28     176
# 3   赵六  24     167
# 4   周武  66     180
# 5   张叶  28     176
# 6   张器  24     167
# 7   李咯  25     180
# 8   王根  28     176
# 9   张灯  24     167
# 10  李放  25     180
# 11  王润  35     176

# %% [markdown]
# #### 批量更新索引

# %% [markdown]
# DataFrame.rename（mapper = None，index = None，columns = None，axis = None，copy = True，inplace = False，level = None ）
#
# 参数介绍：
# mapper，index，columns：可以任选其一使用，可以是将index和columns结合使用。index和column直接传入mapper或者字典的形式。
# axis：int或str，与mapper配合使用。可以是轴名称（‘index’，‘columns’）或数字（0,1）。默认为’index’。
# copy：boolean，默认为True，是否复制基础数据。
# inplace：布尔值，默认为False，是否返回新的DataFrame。如果为True，则忽略复制值。

# %%
df1 = df.rename(lambda x : x + 10)
df1
# Out:
#     姓名  年龄  height
# 10  张三  24     167
# 11  李四  25     180
# 12  王五  28     176
# 13  赵六  24     167
# 14  周武  66     180
# 15  张叶  28     176
# 16  张器  24     167
# 17  李咯  25     180
# 18  王根  28     176
# 19  张灯  24     167
# 20  李放  25     180
# 21  王润  35     176

# %% [markdown]
# #### 批量更新列名

# %%
df2 = df.rename(columns = lambda x : 'T-' + x)
df2
# Out:
#    T-姓名  T-年龄  T-height
# 0    张三    24       167
# 1    李四    25       180
# 2    王五    28       176
# 3    赵六    24       167
# 4    周武    66       180
# 5    张叶    28       176
# 6    张器    24       167
# 7    李咯    25       180
# 8    王根    28       176
# 9    张灯    24       167
# 10   李放    25       180
# 11   王润    35       176

# %% [markdown]
# #### 设置姓名列为行索引

# %%
df21 = df2.set_index('T-姓名')
df21
# Out:
#       T-年龄  T-height
# T-姓名
# 张三      24       167
# 李四      25       180
# 王五      28       176
# 赵六      24       167
# 周武      66       180
# 张叶      28       176
# 张器      24       167
# 李咯      25       180
# 王根      28       176
# 张灯      24       167
# 李放      25       180
# 王润      35       176

# %% [markdown]
# #### 检查哪些列包含缺失值

# %%
df2.isnull().any()
# Out:
# T-姓名        False
# T-年龄        False
# T-height    False
# dtype: bool

# %% [markdown]
# #### 统计各列空值数

# %%
df.isnull().sum()
# Out:
# 姓名        0
# 年龄        0
# height    0
# dtype: int64

# %%
df_data = pd.DataFrame([['张三', 23], ['李四', 25], [None, 27], ['王五', None]], columns = ['姓名', '年龄'])
df_data
# Out:
#      姓名    年龄
# 0    张三  23.0
# 1    李四  25.0
# 2  None  27.0
# 3    王五   NaN

# %% [markdown]
# #### 删除某列中空值的行

# %%
df_data1 = df_data[df_data['姓名'].notnull()]
df_data1
# Out:
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0
# 3  王五   NaN

# %%
df_data2 = df_data[~df_data['姓名'].isnull()]
df_data2
# Out:
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0
# 3  王五   NaN

# %% [markdown]
# #### 去掉某行

# %%
df_data3 = df_data2.drop(0, axis = 0)
df_data3
# Out:
#    姓名    年龄
# 1  李四  25.0
# 3  王五   NaN

# %% [markdown]
# #### 去掉某列

# %%
df_data3.drop('年龄', axis = 1)
# Out:
#    姓名
# 1  李四
# 3  王五

# %% [markdown]
# #### 删除所有包含空值的行

# %%
print(df_data.to_string())
df_data.dropna()
# Out:
#      姓名    年龄
# 0    张三  23.0
# 1    李四  25.0
# 2  None  27.0
# 3    王五   NaN
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0

# %% [markdown]
# #### 删除行里全是空值的行

# %%
df_data.dropna(how = 'all')
# Out:
#      姓名    年龄
# 0    张三  23.0
# 1    李四  25.0
# 2  None  27.0
# 3    王五   NaN

# %% [markdown]
# #### 删除所有包含空值的列

# %%
df_data.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %% [markdown]
# #### 至少保留几个非空值的行

# %%
df_data.dropna(thresh = 2)
# Out:
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0

# %% [markdown]
# #### 至少保留几个非空值的列

# %%
df_data4 = df_data.dropna(axis = 1, thresh = 1)
df_data4
# Out:
#      姓名    年龄
# 0    张三  23.0
# 1    李四  25.0
# 2  None  27.0
# 3    王五   NaN

# %% [markdown]
# #### 行数据向下填充

# %%
df_data4.fillna(method = 'ffill') # 空值复制上面
# Out:
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0
# 2  李四  27.0
# 3  王五  27.0

# %% [markdown]
# #### 列数据向右填充

# %%
df_data4.fillna(method = 'ffill', axis = 1) # 空值复制左边
# Out:
#     姓名    年龄
# 0   张三  23.0
# 1   李四  25.0
# 2  NaN  27.0
# 3   王五    王五

# %% [markdown]
# #### 用0替换所有空值

# %%
df_data4.fillna(0)
# Out:
#    姓名    年龄
# 0  张三  23.0
# 1  李四  25.0
# 2   0  27.0
# 3  王五   0.0

# %% [markdown]
# #### 强制转换数据类型

# %%
df['年龄'].astype('int')
df
# Out:
#     姓名  年龄  height
# 0   张三  24     167
# 1   李四  25     180
# 2   王五  28     176
# 3   赵六  24     167
# 4   周武  66     180
# 5   张叶  28     176
# 6   张器  24     167
# 7   李咯  25     180
# 8   王根  28     176
# 9   张灯  24     167
# 10  李放  25     180
# 11  王润  35     176

# %% [markdown]
# #### 查看某列有多少唯一值

# %%
df['年龄'].unique()
# Out:
# array([24, 25, 28, 66, 35], dtype=int64)

# %% [markdown]
# #### 单值替换

# %%
df_dj = df.replace('张灯', '王天宇')

# %%
df.replace(24, 34)
# Out:
#     姓名  年龄  height
# 0   张三  34     167
# 1   李四  25     180
# 2   王五  28     176
# 3   赵六  34     167
# 4   周武  66     180
# 5   张叶  28     176
# 6   张器  34     167
# 7   李咯  25     180
# 8   王根  28     176
# 9   张灯  34     167
# 10  李放  25     180
# 11  王润  35     176

# %% [markdown]
# #### 多值替换

# %%
df.replace({'张三' : '张三2', '王根' : '王根2', 180 : 181})
# Out:
#      姓名  年龄  height
# 0   张三2  24     167
# 1    李四  25     181
# 2    王五  28     176
# 3    赵六  24     167
# 4    周武  66     181
# 5    张叶  28     176
# 6    张器  24     167
# 7    李咯  25     181
# 8   王根2  28     176
# 9    张灯  24     167
# 10   李放  25     181
# 11   王润  35     176

# %%
df.replace(['张三', '王五', '张叶'], ['张三2', '王五2', '张叶2'])
# Out:
#      姓名  年龄  height
# 0   张三2  24     167
# 1    李四  25     180
# 2   王五2  28     176
# 3    赵六  24     167
# 4    周武  66     180
# 5   张叶2  28     176
# 6    张器  24     167
# 7    李咯  25     180
# 8    王根  28     176
# 9    张灯  24     167
# 10   李放  25     180
# 11   王润  35     176

# %% [markdown]
# #### 多值替换单值

# %%
df.replace(['张三', '王五'], '张三王五')
# Out:
#       姓名  年龄  height
# 0   张三王五  24     167
# 1     李四  25     180
# 2   张三王五  28     176
# 3     赵六  24     167
# 4     周武  66     180
# 5     张叶  28     176
# 6     张器  24     167
# 7     李咯  25     180
# 8     王根  28     176
# 9     张灯  24     167
# 10    李放  25     180
# 11    王润  35     176

# %% [markdown]
# #### 替换某列, 显示需要添加inplace=True

# %%
# 重命名
df.rename(columns = {'height' : '身高'}, inplace = True)
# 添加一列
df.insert(loc = 3, column = '城市', value = '上海')  # 在最后一列后，插入值全为3的c列
df
# Out:
#     姓名  年龄   身高  城市
# 0   张三  24  167  上海
# 1   李四  25  180  上海
# 2   王五  28  176  上海
# 3   赵六  24  167  上海
# 4   周武  66  180  上海
# 5   张叶  28  176  上海
# 6   张器  24  167  上海
# 7   李咯  25  180  上海
# 8   王根  28  176  上海
# 9   张灯  24  167  上海
# 10  李放  25  180  上海
# 11  王润  35  176  上海

# %%
df['年龄'] = df['年龄'].replace(24, 29)
df
# Out:
#     姓名  年龄   身高  城市
# 0   张三  29  167  上海
# 1   李四  25  180  上海
# 2   王五  28  176  上海
# 3   赵六  29  167  上海
# 4   周武  66  180  上海
# 5   张叶  28  176  上海
# 6   张器  29  167  上海
# 7   李咯  25  180  上海
# 8   王根  28  176  上海
# 9   张灯  29  167  上海
# 10  李放  25  180  上海
# 11  王润  35  176  上海

# %% [markdown]
# #### 拆分某列成新的DataFrame

# %%
df1 = df.replace('上海', '上海-浦东-三林')
df2 = df1['城市'].str.split('-', expand = True)
df2.columns = ['城市', '地区', '乡镇']
df2
# Out:
#     城市  地区  乡镇
# 0   上海  浦东  三林
# 1   上海  浦东  三林
# 2   上海  浦东  三林
# 3   上海  浦东  三林
# 4   上海  浦东  三林
# 5   上海  浦东  三林
# 6   上海  浦东  三林
# 7   上海  浦东  三林
# 8   上海  浦东  三林
# 9   上海  浦东  三林
# 10  上海  浦东  三林
# 11  上海  浦东  三林

# %% [markdown]
# #### 某一列类型转换,注意该列类型要一致,包括NaN

# %%
df['身高'] = df['身高'].apply(float)
df
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海

# %% [markdown]
# ### 5.数据切片、筛选

# %% [markdown]
# #### 筛选年龄=25的

# %%
df[df['年龄'] == 25]
# Out:
#     姓名  年龄     身高  城市
# 1   李四  25  180.0  上海
# 7   李咯  25  180.0  上海
# 10  李放  25  180.0  上海

# %% [markdown]
# #### 筛选年龄在某个区间的

# %%
df[df['年龄'].isin([25, 29])]
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 3   赵六  29  167.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海

# %% [markdown]
# #### like查询

# %%
# 包含
df[df['姓名'].str.contains('张', na = False)]
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 5  张叶  28  176.0  上海
# 6  张器  29  167.0  上海
# 9  张灯  29  167.0  上海

# %%
# 以什么开头
df[df['姓名'].str.startswith('李', na = False)]
# Out:
#     姓名  年龄     身高  城市
# 1   李四  25  180.0  上海
# 7   李咯  25  180.0  上海
# 10  李放  25  180.0  上海

# %%
# 以什么结尾
df[df['姓名'].str.endswith('五', na = False)]
# Out:
#    姓名  年龄     身高  城市
# 2  王五  28  176.0  上海

# %% [markdown]
# #### 输出所有姓名,缺失值用指定值填充

# %%
df_data['姓名'].str.cat(sep = '、', na_rep = '空值')
# Out:
# '张三、李四、空值、王五'

# %% [markdown]
# #### 重置索引

# %%
df_data.set_index('姓名')
# Out:
#         年龄
# 姓名
# 张三    23.0
# 李四    25.0
# None  27.0
# 王五     NaN

# %% [markdown]
# #### 读前几行

# %%
df[:3]
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 1  李四  25  180.0  上海
# 2  王五  28  176.0  上海

# %% [markdown]
# #### 读后几行

# %%
df[-3:]
# Out:
#     姓名  年龄     身高  城市
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海

# %% [markdown]
# #### 读几行到几行

# %%
df[2:5]#左闭右开 注意:是从0行开始的
# Out:
#    姓名  年龄     身高  城市
# 2  王五  28  176.0  上海
# 3  赵六  29  167.0  上海
# 4  周武  66  180.0  上海

# %% [markdown]
# #### 每隔几行读取

# %%
df[::2]
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 2   王五  28  176.0  上海
# 4   周武  66  180.0  上海
# 6   张器  29  167.0  上海
# 8   王根  28  176.0  上海
# 10  李放  25  180.0  上海

# %% [markdown]
# #### 几行到几行按指定步长读

# %%
df[2:6:2]
# Out:
#    姓名  年龄     身高  城市
# 2  王五  28  176.0  上海
# 4  周武  66  180.0  上海

# %% [markdown]
# #### 选取其中几列

# %%
df[['姓名','城市']]
# Out:
#     姓名  城市
# 0   张三  上海
# 1   李四  上海
# 2   王五  上海
# 3   赵六  上海
# 4   周武  上海
# 5   张叶  上海
# 6   张器  上海
# 7   李咯  上海
# 8   王根  上海
# 9   张灯  上海
# 10  李放  上海
# 11  王润  上海

# %% [markdown]
# #### loc

# %%
# df.loc[]只能使用标签索引，不能使用整数索引，通过便签索引切边进行筛选时，前闭后闭
# 0行，所有列
df.loc[0, :]
# Out:
# 姓名       张三
# 年龄       29
# 身高    167.0
# 城市       上海
# Name: 0, dtype: object

# %%
# 0 2 3行 所有列
df.loc[[0, 2, 3], :]
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 2  王五  28  176.0  上海
# 3  赵六  29  167.0  上海

# %%
# 0-4行 所有列
df.loc[0 : 4, :]#左闭右闭
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 1  李四  25  180.0  上海
# 2  王五  28  176.0  上海
# 3  赵六  29  167.0  上海
# 4  周武  66  180.0  上海

# %%
# 列索引为'姓名'，所有行
df.loc[:, '姓名']
# Out:
# 0     张三
# 1     李四
# 2     王五
# 3     赵六
# 4     周武
# 5     张叶
# 6     张器
# 7     李咯
# 8     王根
# 9     张灯
# 10    李放
# 11    王润
# Name: 姓名, dtype: object

# %%
# 列索引从姓名到城市
df.loc[:, '姓名' : '城市']
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海

# %%
# 年龄大于28的姓名身高
df.loc[df['年龄'] > 28, ['姓名', '身高']]
# Out:
#     姓名     身高
# 0   张三  167.0
# 3   赵六  167.0
# 4   周武  180.0
# 6   张器  167.0
# 9   张灯  167.0
# 11  王润  176.0

# %%
df.loc[lambda x : x['年龄'] > 28]
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 6   张器  29  167.0  上海
# 9   张灯  29  167.0  上海
# 11  王润  35  176.0  上海

# %%
# 筛选指定行的指定列
df.loc[df['姓名'].isin(['张三', '李四']), '姓名':'城市']
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 1  李四  25  180.0  上海

# %% [markdown]
# #### iloc
# iloc[]只能使用整数索引，不能使用标签索引，
# 通过整数索引切边进行筛选时，前闭后开

# %%
# 前3行
df.iloc[:3]
# Out:
#    姓名  年龄     身高  城市
# 0  张三  29  167.0  上海
# 1  李四  25  180.0  上海
# 2  王五  28  176.0  上海

# %%
# 最后一行
df.iloc[-1:]
# Out:
#     姓名  年龄     身高  城市
# 11  王润  35  176.0  上海

# %%
# 第二列
df.iloc[:, 1]
# Out:
# 0     29
# 1     25
# 2     28
# 3     29
# 4     66
# 5     28
# 6     29
# 7     25
# 8     28
# 9     29
# 10    25
# 11    35
# Name: 年龄, dtype: int64

# %%
# 选取几行
df.iloc[[1, 3, 5], :]
# Out:
#    姓名  年龄     身高  城市
# 1  李四  25  180.0  上海
# 3  赵六  29  167.0  上海
# 5  张叶  28  176.0  上海

# %%
# 选取某个值 
print(df.to_string())
df.iloc[2, 2]#索引值(2,2)对应第3行3列
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海
# 176.0

# %%
# 读取几列
df.iloc[:, [0, 2, 3]]
# Out:
#     姓名     身高  城市
# 0   张三  167.0  上海
# 1   李四  180.0  上海
# 2   王五  176.0  上海
# 3   赵六  167.0  上海
# 4   周武  180.0  上海
# 5   张叶  176.0  上海
# 6   张器  167.0  上海
# 7   李咯  180.0  上海
# 8   王根  176.0  上海
# 9   张灯  167.0  上海
# 10  李放  180.0  上海
# 11  王润  176.0  上海

# %%
# 读取某几行几列
df.iloc[[0, 2], [0, 2, 3]]
# Out:
#    姓名     身高  城市
# 0  张三  167.0  上海
# 2  王五  176.0  上海

# %%
# 前三行三列
df.iloc[:3, :3]
# Out:
#    姓名  年龄     身高
# 0  张三  29  167.0
# 1  李四  25  180.0
# 2  王五  28  176.0

# %% [markdown]
# ### 6.数据排序

# %% [markdown]
# #### 重置索引

# %%
# 设置索引
df3 = df.set_index('姓名')
df3
# Out:
#     年龄     身高  城市
# 姓名
# 张三  29  167.0  上海
# 李四  25  180.0  上海
# 王五  28  176.0  上海
# 赵六  29  167.0  上海
# 周武  66  180.0  上海
# 张叶  28  176.0  上海
# 张器  29  167.0  上海
# 李咯  25  180.0  上海
# 王根  28  176.0  上海
# 张灯  29  167.0  上海
# 李放  25  180.0  上海
# 王润  35  176.0  上海

# %%
# 重置索引
df4 = df3.reset_index()
df4
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海

# %%
# 重置索引并删除原索引列
df5 = df3.reset_index(drop = True)
df5
# Out:
#     年龄     身高  城市
# 0   29  167.0  上海
# 1   25  180.0  上海
# 2   28  176.0  上海
# 3   29  167.0  上海
# 4   66  180.0  上海
# 5   28  176.0  上海
# 6   29  167.0  上海
# 7   25  180.0  上海
# 8   28  176.0  上海
# 9   29  167.0  上海
# 10  25  180.0  上海
# 11  35  176.0  上海

# %% [markdown]
# #### 按某列排序(默认升序)

# %%
df.sort_values('年龄')#升序
df.sort_values('年龄', ascending = False)#降序
# Out:
#     姓名  年龄     身高  城市
# 4   周武  66  180.0  上海
# 11  王润  35  176.0  上海
# 0   张三  29  167.0  上海
# 3   赵六  29  167.0  上海
# 6   张器  29  167.0  上海
# 9   张灯  29  167.0  上海
# 2   王五  28  176.0  上海
# 5   张叶  28  176.0  上海
# 8   王根  28  176.0  上海
# 1   李四  25  180.0  上海
# 7   李咯  25  180.0  上海
# 10  李放  25  180.0  上海

# %% [markdown]
# #### 组合排序

# %%
#先按年龄升序 再按身高降序
df.sort_values(['年龄', '身高'], ascending = [True, False])
# Out:
#     姓名  年龄     身高  城市
# 1   李四  25  180.0  上海
# 7   李咯  25  180.0  上海
# 10  李放  25  180.0  上海
# 2   王五  28  176.0  上海
# 5   张叶  28  176.0  上海
# 8   王根  28  176.0  上海
# 0   张三  29  167.0  上海
# 3   赵六  29  167.0  上海
# 6   张器  29  167.0  上海
# 9   张灯  29  167.0  上海
# 11  王润  35  176.0  上海
# 4   周武  66  180.0  上海

# %% [markdown]
# #### 条件查询

# %%
# 身高175以上
df.query('身高 > 175')
df[df['身高'] > 175]
# Out:
#     姓名  年龄     身高  城市
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 10  李放  25  180.0  上海
# 11  王润  35  176.0  上海

# %%
# 身高180及以上且年龄30以下
df.query('身高 >= 180 & 年龄 < 30')
# Out:
#     姓名  年龄     身高  城市
# 1   李四  25  180.0  上海
# 7   李咯  25  180.0  上海
# 10  李放  25  180.0  上海

# %%
# 身高180及以上或年龄30以下
df.query('身高 >= 180 | 年龄 < 30')
# Out:
#     姓名  年龄     身高  城市
# 0   张三  29  167.0  上海
# 1   李四  25  180.0  上海
# 2   王五  28  176.0  上海
# 3   赵六  29  167.0  上海
# 4   周武  66  180.0  上海
# 5   张叶  28  176.0  上海
# 6   张器  29  167.0  上海
# 7   李咯  25  180.0  上海
# 8   王根  28  176.0  上海
# 9   张灯  29  167.0  上海
# 10  李放  25  180.0  上海

# %% [markdown]
# #### 输出某个值的行和列号

# %%
row, col = np.where(df.values == 28)# 左边是行索引 右边是列索引
print(row)
print(col)
# Out:
# [2 5 8]
# [1 1 1]

# %% [markdown]
# #### 增加一列

# %%
df['地区'] = '浦东'
df['地址'] = df['城市'] + '-' + df['地区']
df
# Out:
#     姓名  年龄     身高  城市  地区     地址
# 0   张三  29  167.0  上海  浦东  上海-浦东
# 1   李四  25  180.0  上海  浦东  上海-浦东
# 2   王五  28  176.0  上海  浦东  上海-浦东
# 3   赵六  29  167.0  上海  浦东  上海-浦东
# 4   周武  66  180.0  上海  浦东  上海-浦东
# 5   张叶  28  176.0  上海  浦东  上海-浦东
# 6   张器  29  167.0  上海  浦东  上海-浦东
# 7   李咯  25  180.0  上海  浦东  上海-浦东
# 8   王根  28  176.0  上海  浦东  上海-浦东
# 9   张灯  29  167.0  上海  浦东  上海-浦东
# 10  李放  25  180.0  上海  浦东  上海-浦东
# 11  王润  35  176.0  上海  浦东  上海-浦东

# %%
df['资产:万'] = np.random.randint(20, 100, 12)
df
# Out:
#     姓名  年龄     身高  城市  地区     地址  资产:万
# 0   张三  29  167.0  上海  浦东  上海-浦东    79
# 1   李四  25  180.0  上海  浦东  上海-浦东    42
# 2   王五  28  176.0  上海  浦东  上海-浦东    93
# 3   赵六  29  167.0  上海  浦东  上海-浦东    89
# 4   周武  66  180.0  上海  浦东  上海-浦东    77
# 5   张叶  28  176.0  上海  浦东  上海-浦东    61
# 6   张器  29  167.0  上海  浦东  上海-浦东    53
# 7   李咯  25  180.0  上海  浦东  上海-浦东    42
# 8   王根  28  176.0  上海  浦东  上海-浦东    65
# 9   张灯  29  167.0  上海  浦东  上海-浦东    58
# 10  李放  25  180.0  上海  浦东  上海-浦东    69
# 11  王润  35  176.0  上海  浦东  上海-浦东    68

# %%
# 增加一列财富评级
def get_level(assets):
    if assets > 90:
        return '富有'
    return '一般' if assets < 50 else '中等' 
df['财富等级'] = df['资产:万'].apply(lambda x : get_level(x))
df
# Out:
#     姓名  年龄     身高  城市  地区     地址  资产:万 财富等级
# 0   张三  29  167.0  上海  浦东  上海-浦东    79   中等
# 1   李四  25  180.0  上海  浦东  上海-浦东    42   一般
# 2   王五  28  176.0  上海  浦东  上海-浦东    93   富有
# 3   赵六  29  167.0  上海  浦东  上海-浦东    89   中等
# 4   周武  66  180.0  上海  浦东  上海-浦东    77   中等
# 5   张叶  28  176.0  上海  浦东  上海-浦东    61   中等
# 6   张器  29  167.0  上海  浦东  上海-浦东    53   中等
# 7   李咯  25  180.0  上海  浦东  上海-浦东    42   一般
# 8   王根  28  176.0  上海  浦东  上海-浦东    65   中等
# 9   张灯  29  167.0  上海  浦东  上海-浦东    58   中等
# 10  李放  25  180.0  上海  浦东  上海-浦东    69   中等
# 11  王润  35  176.0  上海  浦东  上海-浦东    68   中等

# %% [markdown]
# #### 删除行列
# 注意：（1）、删除列的操作时，axis参数不可省，因为axis默认为0（行）；
#
# （2）、没有加入inplace参数，默认不会对原来数据进行修改，需要将结果赋值给新的变量。

# %%
# 删除某行
df6 = df.drop(labels = 0)
df6
# Out:
#     姓名  年龄     身高  城市  地区     地址  资产:万 财富等级
# 1   李四  25  180.0  上海  浦东  上海-浦东    42   一般
# 2   王五  28  176.0  上海  浦东  上海-浦东    93   富有
# 3   赵六  29  167.0  上海  浦东  上海-浦东    89   中等
# 4   周武  66  180.0  上海  浦东  上海-浦东    77   中等
# 5   张叶  28  176.0  上海  浦东  上海-浦东    61   中等
# 6   张器  29  167.0  上海  浦东  上海-浦东    53   中等
# 7   李咯  25  180.0  上海  浦东  上海-浦东    42   一般
# 8   王根  28  176.0  上海  浦东  上海-浦东    65   中等
# 9   张灯  29  167.0  上海  浦东  上海-浦东    58   中等
# 10  李放  25  180.0  上海  浦东  上海-浦东    69   中等
# 11  王润  35  176.0  上海  浦东  上海-浦东    68   中等

# %%
# 删除列
df7 = df.drop(labels = ['城市', '地区'], axis = 1)
df7
# Out:
#     姓名  年龄     身高     地址  资产:万 财富等级
# 0   张三  29  167.0  上海-浦东    79   中等
# 1   李四  25  180.0  上海-浦东    42   一般
# 2   王五  28  176.0  上海-浦东    93   富有
# 3   赵六  29  167.0  上海-浦东    89   中等
# 4   周武  66  180.0  上海-浦东    77   中等
# 5   张叶  28  176.0  上海-浦东    61   中等
# 6   张器  29  167.0  上海-浦东    53   中等
# 7   李咯  25  180.0  上海-浦东    42   一般
# 8   王根  28  176.0  上海-浦东    65   中等
# 9   张灯  29  167.0  上海-浦东    58   中等
# 10  李放  25  180.0  上海-浦东    69   中等
# 11  王润  35  176.0  上海-浦东    68   中等

# %%
del df7['身高']
df7
# Out:
#     姓名  年龄     地址  资产:万 财富等级
# 0   张三  29  上海-浦东    79   中等
# 1   李四  25  上海-浦东    42   一般
# 2   王五  28  上海-浦东    93   富有
# 3   赵六  29  上海-浦东    89   中等
# 4   周武  66  上海-浦东    77   中等
# 5   张叶  28  上海-浦东    61   中等
# 6   张器  29  上海-浦东    53   中等
# 7   李咯  25  上海-浦东    42   一般
# 8   王根  28  上海-浦东    65   中等
# 9   张灯  29  上海-浦东    58   中等
# 10  李放  25  上海-浦东    69   中等
# 11  王润  35  上海-浦东    68   中等

# %% [markdown]
# ### 7.数据分组

# %% [markdown]
# #### 一列分组

# %%
df.groupby('财富等级').groups
# Out:
# {'一般': [1, 7], '中等': [0, 3, 4, 5, 6, 8, 9, 10, 11], '富有': [2]}

# %% [markdown]
# #### 多列分组

# %%
df.groupby(['年龄', '财富等级']).groups
# Out:
# {(25, '一般'): [1, 7], (25, '中等'): [10], (28, '中等'): [5, 8], (28, '富有'): [2], (29, '中等'): [0, 3, 6, 9], (35, '中等'): [11], (66, '中等'): [4]}

# %% [markdown]
# #### 每组的统计数据（横向显示）

# %%
df.groupby('财富等级').describe()
# Out:
#         年龄                                                        身高
#      count       mean        std   min   25%   50%   75%   max count
# 财富等级
# 一般     2.0  25.000000   0.000000  25.0  25.0  25.0  25.0  25.0   2.0  \
# 中等     9.0  33.111111  12.604012  25.0  28.0  29.0  29.0  66.0   9.0
# 富有     1.0  28.000000        NaN  28.0  28.0  28.0  28.0  28.0   1.0
#
#                   ...                资产:万
#             mean  ...    75%    max count       mean        std   min   25%
# 财富等级              ...
# 一般    180.000000  ...  180.0  180.0   2.0  42.000000   0.000000  42.0  42.0  \
# 中等    172.888889  ...  176.0  180.0   9.0  68.777778  11.300197  53.0  61.0
# 富有    176.000000  ...  176.0  176.0   1.0  93.000000        NaN  93.0  93.0
#
#
#        50%   75%   max
# 财富等级
# 一般    42.0  42.0  42.0
# 中等    68.0  77.0  89.0
# 富有    93.0  93.0  93.0
#
# [3 rows x 24 columns]

# %% [markdown]
# #### 每组的统计数据（纵向显示）

# %%
df.groupby('财富等级').describe().unstack()
# Out:
#              财富等级
# 年龄    count  一般       2.000000
#              中等       9.000000
#              富有       1.000000
#       mean   一般      25.000000
#              中等      33.111111
#                        ...
# 资产:万  75%    中等      77.000000
#              富有      93.000000
#       max    一般      42.000000
#              中等      89.000000
#              富有      93.000000
# Length: 72, dtype: float64

# %% [markdown]
# ####  查看指定列的统计信息

# %%
df.groupby('财富等级').describe()['年龄']
# Out:
#       count       mean        std   min   25%   50%   75%   max
# 财富等级
# 一般      2.0  25.000000   0.000000  25.0  25.0  25.0  25.0  25.0
# 中等      9.0  33.111111  12.604012  25.0  28.0  29.0  29.0  66.0
# 富有      1.0  28.000000        NaN  28.0  28.0  28.0  28.0  28.0

# %% [markdown]
# #### 分组大小

# %%
df.groupby('财富等级').count()
df.groupby('年龄').count()
df.groupby('财富等级').agg(np.size)
# Out:
#       姓名  年龄  身高  城市  地区  地址  资产:万
# 财富等级
# 一般     2   2   2   2   2   2     2
# 中等     9   9   9   9   9   9     9
# 富有     1   1   1   1   1   1     1

# %% [markdown]
# #### 分组最大值

# %%
df.groupby('年龄').max()
df.groupby('年龄').agg(np.max)
# Out:
#     姓名     身高  城市  地区     地址  资产:万 财富等级
# 年龄
# 25  李放  180.0  上海  浦东  上海-浦东    69   中等
# 28  王根  176.0  上海  浦东  上海-浦东    93   富有
# 29  赵六  167.0  上海  浦东  上海-浦东    89   中等
# 35  王润  176.0  上海  浦东  上海-浦东    68   中等
# 66  周武  180.0  上海  浦东  上海-浦东    77   中等

# %% [markdown]
# #### 分组最小值

# %%
df.groupby('身高').min()
# Out:
#        姓名  年龄  城市  地区     地址  资产:万 财富等级
# 身高
# 167.0  张三  29  上海  浦东  上海-浦东    53   中等
# 176.0  张叶  28  上海  浦东  上海-浦东    61   中等
# 180.0  周武  25  上海  浦东  上海-浦东    42   一般

# %% [markdown]
# #### 分组求和

# %%
df8 = pd.DataFrame([['一月', 340], ['一月', 440], ['二月', 55], ['二月', 66]], columns = ['月份', '开销'])
print(df8.to_string())
df8.groupby('月份').sum()
# Out:
#    月份   开销
# 0  一月  340
# 1  一月  440
# 2  二月   55
# 3  二月   66
#      开销
# 月份
# 一月  780
# 二月  121

# %% [markdown]
# #### 分组求平均

# %%
df8.groupby('月份').mean()
# Out:
#        开销
# 月份
# 一月  390.0
# 二月   60.5

# %% [markdown]
# #### 同时计算求和和平均

# %%
df8.groupby('月份').agg([np.sum, np.mean])
# Out:
#      开销
#     sum   mean
# 月份
# 一月  780  390.0
# 二月  121   60.5

# %% [markdown]
# #### 不同列不同的计算方法

# %%
df8['收入'] = np.random.randint(7000, 9000, 4)
df8
# Out:
#    月份   开销    收入
# 0  一月  340  8940
# 1  一月  440  7944
# 2  二月   55  8309
# 3  二月   66  7168

# %%
df8.groupby('月份').agg({'开销' : 'count', '收入' : 'sum'})
# Out:
#     开销     收入
# 月份
# 一月   2  16884
# 二月   2  15477

# %% [markdown]
# #### 值映射

# %%
df8['月份'] = df8['月份'].map({'一月' : 1, '二月' : 2})
df8
# Out:
#    月份   开销    收入
# 0   1  340  8940
# 1   1  440  7944
# 2   2   55  8309
# 3   2   66  7168

# %% [markdown]
# #### 增加一列分组求出的值

# %%
df8['平均收入'] = df8.groupby('月份')['收入'].transform('mean')
df8
# Out:
#    月份   开销    收入    平均收入
# 0   1  340  8940  8442.0
# 1   1  440  7944  8442.0
# 2   2   55  8309  7738.5
# 3   2   66  7168  7738.5

# %% [markdown]
# #### 输出月份分组收入最高（groupby默认会去掉空值）

# %%
def get_max(g):
    df = g.sort_values('收入', ascending = True)
    return df.iloc[-1, :]
df8.groupby('月份').apply(get_max)
# Out:
#      月份     开销      收入    平均收入
# 月份
# 1   1.0  340.0  8940.0  8442.0
# 2   2.0   55.0  8309.0  7738.5

# %% [markdown]
# #### 准备示例数据

# %%
# 数据准备
columns = ['姓名','性别','语文','数学','英语','城市','省份/市']
df9 = pd.DataFrame(columns = columns)

def random_name():
    # 删减部分小众姓氏
    firstName = "赵钱孙李周吴郑王冯陈褚卫蒋沈韩杨朱秦尤许何吕施张孔曹严华金魏陶姜戚谢邹喻水云苏潘葛奚范彭郎鲁韦昌马苗凤花方俞任袁柳鲍史唐费岑薛雷贺倪汤滕殷罗毕郝邬安常乐于时傅卞齐康伍余元卜顾孟平" \
                "黄和穆萧尹姚邵湛汪祁毛禹狄米贝明臧计成戴宋茅庞熊纪舒屈项祝董粱杜阮席季麻强贾路娄危江童颜郭梅盛林刁钟徐邱骆高夏蔡田胡凌霍万柯卢莫房缪干解应宗丁宣邓郁单杭洪包诸左石崔吉" \
                "龚程邢滑裴陆荣翁荀羊甄家封芮储靳邴松井富乌焦巴弓牧隗山谷车侯伊宁仇祖武符刘景詹束龙叶幸司韶黎乔苍双闻莘劳逄姬冉宰桂牛寿通边燕冀尚农温庄晏瞿茹习鱼容向古戈终居衡步都耿满弘国文东殴沃曾关红游盖益桓公晋楚闫"
    # 百家姓姓氏
    # firstName = "赵钱孙李周吴郑王冯陈褚卫蒋沈韩杨朱秦尤许何吕施张孔曹严华金魏陶姜戚谢邹喻柏水窦章云苏潘葛奚范彭郎鲁韦昌马苗凤花方俞任袁柳酆鲍史唐费廉岑薛雷贺倪汤滕殷罗毕郝邬安常乐于时傅皮卞齐康伍余元卜顾孟平" \
    #             "黄和穆萧尹姚邵湛汪祁毛禹狄米贝明臧计伏成戴谈宋茅庞熊纪舒屈项祝董粱杜阮蓝闵席季麻强贾路娄危江童颜郭梅盛林刁钟徐邱骆高夏蔡田樊胡凌霍虞万支柯昝管卢莫经房裘缪干解应宗丁宣贲邓郁单杭洪包诸左石崔吉钮" \
    #             "龚程嵇邢滑裴陆荣翁荀羊於惠甄麴家封芮羿储靳汲邴糜松井段富巫乌焦巴弓牧隗山谷车侯宓蓬全郗班仰秋仲伊宫宁仇栾暴甘钭厉戎祖武符刘景詹束龙叶幸司韶郜黎蓟薄印宿白怀蒲邰从鄂索咸籍赖卓蔺屠蒙池乔阴欎胥能苍" \
    #             "双闻莘党翟谭贡劳逄姬申扶堵冉宰郦雍舄璩桑桂濮牛寿通边扈燕冀郏浦尚农温别庄晏柴瞿阎充慕连茹习宦艾鱼容向古易慎戈廖庾终暨居衡步都耿满弘匡国文寇广禄阙东殴殳沃利蔚越夔隆师巩厍聂晁勾敖融冷訾辛阚那简饶空" \
    #             "曾毋沙乜养鞠须丰巢关蒯相查後荆红游竺权逯盖益桓公晋楚闫法汝鄢涂钦归海帅缑亢况后有琴梁丘左丘商牟佘佴伯赏南宫墨哈谯笪年爱阳佟言福百家姓终"
    # 百家姓中双姓氏
    firstName2="万俟司马上官欧阳夏侯诸葛闻人东方赫连皇甫尉迟公羊澹台公冶宗政濮阳淳于单于太叔申屠公孙仲孙轩辕令狐钟离宇文长孙慕容鲜于闾丘司徒司空亓官司寇仉督子颛孙端木巫马公西漆雕乐正壤驷公良拓跋夹谷宰父谷梁段干百里东郭南门呼延羊舌微生梁丘左丘东门西门南宫南宫"
    # 女孩名字
    girl = '秀娟英华慧巧美娜静淑惠珠翠雅芝玉萍红娥玲芬芳燕彩春菊兰凤洁梅琳素云莲真环雪荣爱妹霞香月莺媛艳瑞凡佳嘉琼勤珍贞莉桂娣叶璧璐娅琦晶妍茜秋珊莎锦黛青倩婷姣婉娴瑾颖露瑶怡婵雁蓓纨仪荷丹蓉眉君琴蕊薇菁梦岚苑婕馨瑗琰韵融园艺咏卿聪澜纯毓悦昭冰爽琬茗羽希宁欣飘育滢馥筠柔竹霭凝晓欢霄枫芸菲寒伊亚宜可姬舒影荔枝思丽'
    # 男孩名字
    boy = '伟刚勇毅俊峰强军平保东文辉力明永健世广志义兴良海山仁波宁贵福生龙元全国胜学祥才发武新利清飞彬富顺信子杰涛昌成康星光天达安岩中茂进林有坚和彪博诚先敬震振壮会思群豪心邦承乐绍功松善厚庆磊民友裕河哲江超浩亮政谦亨奇固之轮翰朗伯宏言若鸣朋斌梁栋维启克伦翔旭鹏泽晨辰士以建家致树炎德行时泰盛雄琛钧冠策腾楠榕风航弘'
    # 名
    name = '中笑贝凯歌易仁器义礼智信友上都卡被好无九加电金马钰玉忠孝'
 
    # 10%的机遇生成双数姓氏
    if np.random.choice(range(100))>10:
        firstName_name =firstName[np.random.choice(range(len(firstName)))]
    else:
        i = np.random.choice(range(len(firstName2)))
        firstName_name =firstName2[i:i+2]
 
    sex = np.random.choice(range(2))
    name_1 = ""
    # 生成并返回一个名字
    if sex > 0:
        girl_name = girl[np.random.choice(range(len(girl)))]
        if np.random.choice(range(2)) > 0:
            name_1 = name[np.random.choice(range(len(name)))]
        return firstName_name + name_1 + girl_name
    else:
        boy_name = boy[np.random.choice(range(len(boy)))]
        if np.random.choice(range(2)) > 0:
            name_1 = name[np.random.choice(range(len(name)))]
        return firstName_name + name_1 + boy_name
# 随机获得n个姓名
def get_peoples(n):
    peoples = []
    for i in range(n):
        peoples.append(random_name())
    return peoples
# 随机获得n个性别
def get_genders(n):
    genders = []
    for i in range(n):
        genders.append('男' if np.random.random() < 0.4 else '女')
    return genders
# 随机获得n个成绩
def get_scores(n):
    return np.random.randint(40, 100, n)

city = ['安徽-合肥', '安徽-滁州', '安徽-蚌埠', '安徽-芜湖' ,\
        '上海-浦东', '上海-徐汇', '上海-闵行', '上海-松江']
# 从上面随机获得n个城市
def get_citys(n):
    citys = []
    for i in range(n):
        citys.append(city[np.random.randint(0, 7)])
    return citys

# %%
# '姓名','性别','语文','数学','英语','城市','省份/市'
nums = 30
df9['姓名'] = get_peoples(nums)
df9['性别'] = get_genders(nums)
df9['语文'] = get_scores(nums)
df9['数学'] = get_scores(nums)
df9['英语'] = get_scores(nums)
df9['省份/市'] = get_citys(nums)
df9
# Out:
#       姓名 性别  语文  数学  英语   城市   省份/市
# 0     彭芸  女  88  43  49  NaN  安徽-芜湖
# 1    薛加娟  男  81  77  70  NaN  上海-浦东
# 2    萧忠峰  男  45  43  79  NaN  安徽-芜湖
# 3    国礼涛  女  65  45  46  NaN  上海-浦东
# 4    乔忠之  女  55  62  40  NaN  安徽-蚌埠
# 5    束被永  男  45  50  97  NaN  安徽-蚌埠
# 6    罗孝翔  女  89  50  97  NaN  上海-闵行
# 7     赵秀  男  87  41  71  NaN  上海-闵行
# 8     彭姣  女  53  94  80  NaN  安徽-滁州
# 9    路笑娣  男  61  95  61  NaN  上海-闵行
# 10   骆贝静  男  48  59  79  NaN  安徽-合肥
# 11    劳刚  男  82  94  90  NaN  上海-闵行
# 12   孟被良  男  79  53  58  NaN  安徽-蚌埠
# 13   燕器伦  女  76  50  47  NaN  安徽-芜湖
# 14    燕欣  女  49  43  91  NaN  安徽-蚌埠
# 15   鲍卡东  女  41  71  44  NaN  上海-闵行
# 16   公羊芸  女  42  67  84  NaN  上海-徐汇
# 17  侯诸好亮  女  93  54  55  NaN  上海-浦东
# 18    卞荣  女  63  49  65  NaN  上海-浦东
# 19   于九倩  男  40  82  80  NaN  安徽-芜湖
# 20   丁信娜  女  50  46  69  NaN  安徽-蚌埠
# 21   黄金琳  女  42  91  95  NaN  上海-浦东
# 22    弘叶  女  89  84  80  NaN  上海-浦东
# 23    季海  女  57  46  55  NaN  安徽-滁州
# 24    危凡  男  64  57  53  NaN  安徽-滁州
# 25   贝笑黛  男  88  70  45  NaN  安徽-蚌埠
# 26    苗元  男  82  77  51  NaN  安徽-合肥
# 27    幸婷  男  78  92  43  NaN  上海-闵行
# 28    粱仪  女  50  46  68  NaN  安徽-蚌埠
# 29    都婷  女  67  62  90  NaN  安徽-芜湖

# %%
# 提取信息
df9['城市'] = df9['省份/市'].str.extract(r'-(.*)', expand = False)
df9['省份/市'] = df9['省份/市'].str.extract(r'(.*)-', expand = False)
df9
# Out:
#       姓名 性别  语文  数学  英语  城市 省份/市
# 0     彭芸  女  88  43  49  芜湖   安徽
# 1    薛加娟  男  81  77  70  浦东   上海
# 2    萧忠峰  男  45  43  79  芜湖   安徽
# 3    国礼涛  女  65  45  46  浦东   上海
# 4    乔忠之  女  55  62  40  蚌埠   安徽
# 5    束被永  男  45  50  97  蚌埠   安徽
# 6    罗孝翔  女  89  50  97  闵行   上海
# 7     赵秀  男  87  41  71  闵行   上海
# 8     彭姣  女  53  94  80  滁州   安徽
# 9    路笑娣  男  61  95  61  闵行   上海
# 10   骆贝静  男  48  59  79  合肥   安徽
# 11    劳刚  男  82  94  90  闵行   上海
# 12   孟被良  男  79  53  58  蚌埠   安徽
# 13   燕器伦  女  76  50  47  芜湖   安徽
# 14    燕欣  女  49  43  91  蚌埠   安徽
# 15   鲍卡东  女  41  71  44  闵行   上海
# 16   公羊芸  女  42  67  84  徐汇   上海
# 17  侯诸好亮  女  93  54  55  浦东   上海
# 18    卞荣  女  63  49  65  浦东   上海
# 19   于九倩  男  40  82  80  芜湖   安徽
# 20   丁信娜  女  50  46  69  蚌埠   安徽
# 21   黄金琳  女  42  91  95  浦东   上海
# 22    弘叶  女  89  84  80  浦东   上海
# 23    季海  女  57  46  55  滁州   安徽
# 24    危凡  男  64  57  53  滁州   安徽
# 25   贝笑黛  男  88  70  45  蚌埠   安徽
# 26    苗元  男  82  77  51  合肥   安徽
# 27    幸婷  男  78  92  43  闵行   上海
# 28    粱仪  女  50  46  68  蚌埠   安徽
# 29    都婷  女  67  62  90  芜湖   安徽

# %%
df10 = pd.DataFrame(df9, columns = ['姓名','性别','语文','数学','英语','省份/市','城市'])
df10
# Out:
#       姓名 性别  语文  数学  英语 省份/市  城市
# 0     彭芸  女  88  43  49   安徽  芜湖
# 1    薛加娟  男  81  77  70   上海  浦东
# 2    萧忠峰  男  45  43  79   安徽  芜湖
# 3    国礼涛  女  65  45  46   上海  浦东
# 4    乔忠之  女  55  62  40   安徽  蚌埠
# 5    束被永  男  45  50  97   安徽  蚌埠
# 6    罗孝翔  女  89  50  97   上海  闵行
# 7     赵秀  男  87  41  71   上海  闵行
# 8     彭姣  女  53  94  80   安徽  滁州
# 9    路笑娣  男  61  95  61   上海  闵行
# 10   骆贝静  男  48  59  79   安徽  合肥
# 11    劳刚  男  82  94  90   上海  闵行
# 12   孟被良  男  79  53  58   安徽  蚌埠
# 13   燕器伦  女  76  50  47   安徽  芜湖
# 14    燕欣  女  49  43  91   安徽  蚌埠
# 15   鲍卡东  女  41  71  44   上海  闵行
# 16   公羊芸  女  42  67  84   上海  徐汇
# 17  侯诸好亮  女  93  54  55   上海  浦东
# 18    卞荣  女  63  49  65   上海  浦东
# 19   于九倩  男  40  82  80   安徽  芜湖
# 20   丁信娜  女  50  46  69   安徽  蚌埠
# 21   黄金琳  女  42  91  95   上海  浦东
# 22    弘叶  女  89  84  80   上海  浦东
# 23    季海  女  57  46  55   安徽  滁州
# 24    危凡  男  64  57  53   安徽  滁州
# 25   贝笑黛  男  88  70  45   安徽  蚌埠
# 26    苗元  男  82  77  51   安徽  合肥
# 27    幸婷  男  78  92  43   上海  闵行
# 28    粱仪  女  50  46  68   安徽  蚌埠
# 29    都婷  女  67  62  90   安徽  芜湖

# %%
# 7.16 输出语文成绩最高的男生和女生（groupby默认会去掉空值）
def get_max(g):
    df = g.sort_values('语文',ascending=True)
    print(df)
    return df.iloc[-1,:]
df10.groupby('性别').apply(get_max)
# Out:
#       姓名 性别  语文  数学  英语 省份/市  城市
# 15   鲍卡东  女  41  71  44   上海  闵行
# 16   公羊芸  女  42  67  84   上海  徐汇
# 21   黄金琳  女  42  91  95   上海  浦东
# 14    燕欣  女  49  43  91   安徽  蚌埠
# 28    粱仪  女  50  46  68   安徽  蚌埠
# 20   丁信娜  女  50  46  69   安徽  蚌埠
# 8     彭姣  女  53  94  80   安徽  滁州
# 4    乔忠之  女  55  62  40   安徽  蚌埠
# 23    季海  女  57  46  55   安徽  滁州
# 18    卞荣  女  63  49  65   上海  浦东
# 3    国礼涛  女  65  45  46   上海  浦东
# 29    都婷  女  67  62  90   安徽  芜湖
# 13   燕器伦  女  76  50  47   安徽  芜湖
# 0     彭芸  女  88  43  49   安徽  芜湖
# 22    弘叶  女  89  84  80   上海  浦东
# 6    罗孝翔  女  89  50  97   上海  闵行
# 17  侯诸好亮  女  93  54  55   上海  浦东
#      姓名 性别  语文  数学  英语 省份/市  城市
# 19  于九倩  男  40  82  80   安徽  芜湖
# 2   萧忠峰  男  45  43  79   安徽  芜湖
# 5   束被永  男  45  50  97   安徽  蚌埠
# 10  骆贝静  男  48  59  79   安徽  合肥
# 9   路笑娣  男  61  95  61   上海  闵行
# 24   危凡  男  64  57  53   安徽  滁州
# 27   幸婷  男  78  92  43   上海  闵行
# 12  孟被良  男  79  53  58   安徽  蚌埠
# 1   薛加娟  男  81  77  70   上海  浦东
# 11   劳刚  男  82  94  90   上海  闵行
# 26   苗元  男  82  77  51   安徽  合肥
# 7    赵秀  男  87  41  71   上海  闵行
# 25  贝笑黛  男  88  70  45   安徽  蚌埠
#       姓名 性别  语文  数学  英语 省份/市  城市
# 性别
# 女   侯诸好亮  女  93  54  55   上海  浦东
# 男    贝笑黛  男  88  70  45   安徽  蚌埠

# %% [markdown]
# #### 透视表
#
# 按列省份、城市进行分组，计算语文、数学、英语成绩最大值的透视表

# %%
df10.pivot_table(index= ['省份/市', '城市'], values = ['语文', '数学', '英语'], aggfunc = max)
# Out:
#          数学  英语  语文
# 省份/市 城市
# 上海   徐汇  67  84  42
#      浦东  91  95  93
#      闵行  95  97  89
# 安徽   合肥  77  79  82
#      滁州  94  80  64
#      芜湖  82  90  88
#      蚌埠  70  97  88

# %% [markdown]
# ### 8.数据统计

# %% [markdown]
# #### 数据汇总统计

# %%
df10.describe()#数字类型的各个常用指标
# Out:
#               语文         数学         英语
# count  30.000000  30.000000  30.000000
# mean   64.966667  63.100000  67.733333
# std    17.796713  18.295185  18.250996
# min    40.000000  41.000000  40.000000
# 25%    49.250000  46.750000  51.500000
# 50%    63.500000  58.000000  68.500000
# 75%    81.750000  77.000000  80.000000
# max    93.000000  95.000000  97.000000

# %% [markdown]
# #### 各个列非空值的个数

# %%
df10.count()
# Out:
# 姓名      30
# 性别      30
# 语文      30
# 数学      30
# 英语      30
# 省份/市    30
# 城市      30
# dtype: int64

# %% [markdown]
# #### 最值/均值/中位数/列间相关系数/列的标准差/方差

# %%
# 最小
df10.min()#各个列的最小值
df10['语文'].min()#某个列的最小值
# 最大
df10.max()
# 均值
df10['语文'].mean()
# 中位数
df10['语文'].median()
# Out:
# 63.5

# %%
# 列间相关系数
df11 = pd.DataFrame(df10, columns = ['语文', '数学', '英语'])
df11.corr()
# Out:
#           语文        数学        英语
# 语文  1.000000  0.007742 -0.277009
# 数学  0.007742  1.000000  0.093646
# 英语 -0.277009  0.093646  1.000000

# %%
# 标准差
df11.std()
# 方差
df11.var()
# 求和
df11.sum()
# Out:
# 语文    1949
# 数学    1893
# 英语    2032
# dtype: int64

# %%
# 8.10 三个科目的指标
mean = df11[['语文','数学','英语']].mean()
var  = df11[['语文','数学','英语']].var()
total = df11[['语文','数学','英语']].sum()
std = df11[['语文','数学','英语']].std()
rows = [total,mean,var,std]
# 索引列表
index = ['总分','平均分','方差','标准差']
# 根据指定索引和行构造 DataFrame 对象
df_tmp = pd.DataFrame(rows, index = index)
df_tmp
# Out:
#               语文           数学           英语
# 总分   1949.000000  1893.000000  2032.000000
# 平均分    64.966667    63.100000    67.733333
# 方差    316.722989   334.713793   333.098851
# 标准差    17.796713    18.295185    18.250996

# %% [markdown]
# ### 9.表格样式

# %% [markdown]
# #### 设置空值背景为红色

# %%
df_data.style.highlight_null(color = 'red')
# Out:
# <style type="text/css">
# #T_bf1ec_row2_col0, #T_bf1ec_row3_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_bf1ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf1ec_level0_col0" class="col_heading level0 col0" >姓名</th>
#       <th id="T_bf1ec_level0_col1" class="col_heading level0 col1" >年龄</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf1ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf1ec_row0_col0" class="data row0 col0" >张三</td>
#       <td id="T_bf1ec_row0_col1" class="data row0 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf1ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bf1ec_row1_col0" class="data row1 col0" >李四</td>
#       <td id="T_bf1ec_row1_col1" class="data row1 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf1ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bf1ec_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_bf1ec_row2_col1" class="data row2 col1" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf1ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bf1ec_row3_col0" class="data row3 col0" >王五</td>
#       <td id="T_bf1ec_row3_col1" class="data row3 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 最大数据高亮

# %%
df10.style.highlight_max(color = 'green')
# Out:
# <style type="text/css">
# #T_72772_row0_col5, #T_72772_row1_col1, #T_72772_row2_col1, #T_72772_row2_col5, #T_72772_row4_col5, #T_72772_row5_col1, #T_72772_row5_col4, #T_72772_row5_col5, #T_72772_row6_col4, #T_72772_row6_col6, #T_72772_row7_col1, #T_72772_row7_col6, #T_72772_row8_col5, #T_72772_row9_col1, #T_72772_row9_col3, #T_72772_row9_col6, #T_72772_row10_col1, #T_72772_row10_col5, #T_72772_row11_col1, #T_72772_row11_col6, #T_72772_row12_col1, #T_72772_row12_col5, #T_72772_row13_col5, #T_72772_row14_col5, #T_72772_row15_col6, #T_72772_row17_col2, #T_72772_row19_col1, #T_72772_row19_col5, #T_72772_row20_col5, #T_72772_row21_col0, #T_72772_row23_col5, #T_72772_row24_col1, #T_72772_row24_col5, #T_72772_row25_col1, #T_72772_row25_col5, #T_72772_row26_col1, #T_72772_row26_col5, #T_72772_row27_col1, #T_72772_row27_col6, #T_72772_row28_col5, #T_72772_row29_col5 {
#   background-color: green;
# }
# </style>
# <table id="T_72772">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72772_level0_col0" class="col_heading level0 col0" >姓名</th>
#       <th id="T_72772_level0_col1" class="col_heading level0 col1" >性别</th>
#       <th id="T_72772_level0_col2" class="col_heading level0 col2" >语文</th>
#       <th id="T_72772_level0_col3" class="col_heading level0 col3" >数学</th>
#       <th id="T_72772_level0_col4" class="col_heading level0 col4" >英语</th>
#       <th id="T_72772_level0_col5" class="col_heading level0 col5" >省份/市</th>
#       <th id="T_72772_level0_col6" class="col_heading level0 col6" >城市</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72772_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72772_row0_col0" class="data row0 col0" >彭芸</td>
#       <td id="T_72772_row0_col1" class="data row0 col1" >女</td>
#       <td id="T_72772_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_72772_row0_col3" class="data row0 col3" >43</td>
#       <td id="T_72772_row0_col4" class="data row0 col4" >49</td>
#       <td id="T_72772_row0_col5" class="data row0 col5" >安徽</td>
#       <td id="T_72772_row0_col6" class="data row0 col6" >芜湖</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72772_row1_col0" class="data row1 col0" >薛加娟</td>
#       <td id="T_72772_row1_col1" class="data row1 col1" >男</td>
#       <td id="T_72772_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_72772_row1_col3" class="data row1 col3" >77</td>
#       <td id="T_72772_row1_col4" class="data row1 col4" >70</td>
#       <td id="T_72772_row1_col5" class="data row1 col5" >上海</td>
#       <td id="T_72772_row1_col6" class="data row1 col6" >浦东</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72772_row2_col0" class="data row2 col0" >萧忠峰</td>
#       <td id="T_72772_row2_col1" class="data row2 col1" >男</td>
#       <td id="T_72772_row2_col2" class="data row2 col2" >45</td>
#       <td id="T_72772_row2_col3" class="data row2 col3" >43</td>
#       <td id="T_72772_row2_col4" class="data row2 col4" >79</td>
#       <td id="T_72772_row2_col5" class="data row2 col5" >安徽</td>
#       <td id="T_72772_row2_col6" class="data row2 col6" >芜湖</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72772_row3_col0" class="data row3 col0" >国礼涛</td>
#       <td id="T_72772_row3_col1" class="data row3 col1" >女</td>
#       <td id="T_72772_row3_col2" class="data row3 col2" >65</td>
#       <td id="T_72772_row3_col3" class="data row3 col3" >45</td>
#       <td id="T_72772_row3_col4" class="data row3 col4" >46</td>
#       <td id="T_72772_row3_col5" class="data row3 col5" >上海</td>
#       <td id="T_72772_row3_col6" class="data row3 col6" >浦东</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72772_row4_col0" class="data row4 col0" >乔忠之</td>
#       <td id="T_72772_row4_col1" class="data row4 col1" >女</td>
#       <td id="T_72772_row4_col2" class="data row4 col2" >55</td>
#       <td id="T_72772_row4_col3" class="data row4 col3" >62</td>
#       <td id="T_72772_row4_col4" class="data row4 col4" >40</td>
#       <td id="T_72772_row4_col5" class="data row4 col5" >安徽</td>
#       <td id="T_72772_row4_col6" class="data row4 col6" >蚌埠</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_72772_row5_col0" class="data row5 col0" >束被永</td>
#       <td id="T_72772_row5_col1" class="data row5 col1" >男</td>
#       <td id="T_72772_row5_col2" class="data row5 col2" >45</td>
#       <td id="T_72772_row5_col3" class="data row5 col3" >50</td>
#       <td id="T_72772_row5_col4" class="data row5 col4" >97</td>
#       <td id="T_72772_row5_col5" class="data row5 col5" >安徽</td>
#       <td id="T_72772_row5_col6" class="data row5 col6" >蚌埠</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_72772_row6_col0" class="data row6 col0" >罗孝翔</td>
#       <td id="T_72772_row6_col1" class="data row6 col1" >女</td>
#       <td id="T_72772_row6_col2" class="data row6 col2" >89</td>
#       <td id="T_72772_row6_col3" class="data row6 col3" >50</td>
#       <td id="T_72772_row6_col4" class="data row6 col4" >97</td>
#       <td id="T_72772_row6_col5" class="data row6 col5" >上海</td>
#       <td id="T_72772_row6_col6" class="data row6 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_72772_row7_col0" class="data row7 col0" >赵秀</td>
#       <td id="T_72772_row7_col1" class="data row7 col1" >男</td>
#       <td id="T_72772_row7_col2" class="data row7 col2" >87</td>
#       <td id="T_72772_row7_col3" class="data row7 col3" >41</td>
#       <td id="T_72772_row7_col4" class="data row7 col4" >71</td>
#       <td id="T_72772_row7_col5" class="data row7 col5" >上海</td>
#       <td id="T_72772_row7_col6" class="data row7 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_72772_row8_col0" class="data row8 col0" >彭姣</td>
#       <td id="T_72772_row8_col1" class="data row8 col1" >女</td>
#       <td id="T_72772_row8_col2" class="data row8 col2" >53</td>
#       <td id="T_72772_row8_col3" class="data row8 col3" >94</td>
#       <td id="T_72772_row8_col4" class="data row8 col4" >80</td>
#       <td id="T_72772_row8_col5" class="data row8 col5" >安徽</td>
#       <td id="T_72772_row8_col6" class="data row8 col6" >滁州</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_72772_row9_col0" class="data row9 col0" >路笑娣</td>
#       <td id="T_72772_row9_col1" class="data row9 col1" >男</td>
#       <td id="T_72772_row9_col2" class="data row9 col2" >61</td>
#       <td id="T_72772_row9_col3" class="data row9 col3" >95</td>
#       <td id="T_72772_row9_col4" class="data row9 col4" >61</td>
#       <td id="T_72772_row9_col5" class="data row9 col5" >上海</td>
#       <td id="T_72772_row9_col6" class="data row9 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_72772_row10_col0" class="data row10 col0" >骆贝静</td>
#       <td id="T_72772_row10_col1" class="data row10 col1" >男</td>
#       <td id="T_72772_row10_col2" class="data row10 col2" >48</td>
#       <td id="T_72772_row10_col3" class="data row10 col3" >59</td>
#       <td id="T_72772_row10_col4" class="data row10 col4" >79</td>
#       <td id="T_72772_row10_col5" class="data row10 col5" >安徽</td>
#       <td id="T_72772_row10_col6" class="data row10 col6" >合肥</td>
#     </tr>
#     <tr>
#       <th id="T_72772_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_72772_row11_col0" class="data row11 col0" >劳刚</td>
#       <td id="T_72772_row11_col1" class="data row11 col1" >男</td>
#       <td id="T_72772_row11_col2" class="data row11 col2" >82</td>
#       <td id="T_72772_row11_col3" class="data row11 col3" >94</td>
#       <td id="T_72772_row11_col4" cl

# %% [markdown]
# #### 部分列最大数据高亮

# %%
# 9.7 部分列数据高亮（Dataframe全为数据）
# df3 = df[['语文','数学','英语']]
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

df11.style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_de7ae_row5_col2, #T_de7ae_row6_col2, #T_de7ae_row9_col1, #T_de7ae_row17_col0 {
#   background-color: yellow;
# }
# </style>
# <table id="T_de7ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de7ae_level0_col0" class="col_heading level0 col0" >语文</th>
#       <th id="T_de7ae_level0_col1" class="col_heading level0 col1" >数学</th>
#       <th id="T_de7ae_level0_col2" class="col_heading level0 col2" >英语</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de7ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de7ae_row0_col0" class="data row0 col0" >88</td>
#       <td id="T_de7ae_row0_col1" class="data row0 col1" >43</td>
#       <td id="T_de7ae_row0_col2" class="data row0 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de7ae_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_de7ae_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_de7ae_row1_col2" class="data row1 col2" >70</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_de7ae_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_de7ae_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_de7ae_row2_col2" class="data row2 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_de7ae_row3_col0" class="data row3 col0" >65</td>
#       <td id="T_de7ae_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_de7ae_row3_col2" class="data row3 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_de7ae_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_de7ae_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_de7ae_row4_col2" class="data row4 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_de7ae_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_de7ae_row5_col1" class="data row5 col1" >50</td>
#       <td id="T_de7ae_row5_col2" class="data row5 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_de7ae_row6_col0" class="data row6 col0" >89</td>
#       <td id="T_de7ae_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_de7ae_row6_col2" class="data row6 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_de7ae_row7_col0" class="data row7 col0" >87</td>
#       <td id="T_de7ae_row7_col1" class="data row7 col1" >41</td>
#       <td id="T_de7ae_row7_col2" class="data row7 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_de7ae_row8_col0" class="data row8 col0" >53</td>
#       <td id="T_de7ae_row8_col1" class="data row8 col1" >94</td>
#       <td id="T_de7ae_row8_col2" class="data row8 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_de7ae_row9_col0" class="data row9 col0" >61</td>
#       <td id="T_de7ae_row9_col1" class="data row9 col1" >95</td>
#       <td id="T_de7ae_row9_col2" class="data row9 col2" >61</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_de7ae_row10_col0" class="data row10 col0" >48</td>
#       <td id="T_de7ae_row10_col1" class="data row10 col1" >59</td>
#       <td id="T_de7ae_row10_col2" class="data row10 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_de7ae_row11_col0" class="data row11 col0" >82</td>
#       <td id="T_de7ae_row11_col1" class="data row11 col1" >94</td>
#       <td id="T_de7ae_row11_col2" class="data row11 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_de7ae_row12_col0" class="data row12 col0" >79</td>
#       <td id="T_de7ae_row12_col1" class="data row12 col1" >53</td>
#       <td id="T_de7ae_row12_col2" class="data row12 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_de7ae_row13_col0" class="data row13 col0" >76</td>
#       <td id="T_de7ae_row13_col1" class="data row13 col1" >50</td>
#       <td id="T_de7ae_row13_col2" class="data row13 col2" >47</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_de7ae_row14_col0" class="data row14 col0" >49</td>
#       <td id="T_de7ae_row14_col1" class="data row14 col1" >43</td>
#       <td id="T_de7ae_row14_col2" class="data row14 col2" >91</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_de7ae_row15_col0" class="data row15 col0" >41</td>
#       <td id="T_de7ae_row15_col1" class="data row15 col1" >71</td>
#       <td id="T_de7ae_row15_col2" class="data row15 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_de7ae_row16_col0" class="data row16 col0" >42</td>
#       <td id="T_de7ae_row16_col1" class="data row16 col1" >67</td>
#       <td id="T_de7ae_row16_col2" class="data row16 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_de7ae_row17_col0" class="data row17 col0" >93</td>
#       <td id="T_de7ae_row17_col1" class="data row17 col1" >54</td>
#       <td id="T_de7ae_row17_col2" class="data row17 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_de7ae_row18_col0" class="data row18 col0" >63</td>
#       <td id="T_de7ae_row18_col1" class="data row18 col1" >49</td>
#       <td id="T_de7ae_row18_col2" class="data row18 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_de7ae_row19_col0" class="data row19 col0" >40</td>
#       <td id="T_de7ae_row19_col1" class="data row19 col1" >82</td>
#       <td id="T_de7ae_row19_col2" class="data row19 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_de7ae_row20_col0" class="data row20 col0" >50</td>
#       <td id="T_de7ae_row20_col1" class="data row20 col1" >46</td>
#       <td id="T_de7ae_row20_col2" class="data row20 col2" >69</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_de7ae_row21_col0" class="data row21 col0" >42</td>
#       <td id="T_de7ae_row21_col1" class="data row21 col1" >91</td>
#       <td id="T_de7ae_row21_col2" class="data row21 col2" >95</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_de7ae_row22_col0" class="data row22 col0" >89</td>
#       <td id="T_de7ae_row22_col1" class="data row22 col1" >84</td>
#       <td id="T_de7ae_row22_col2" class="data row22 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_de7ae_row23_col0" class="data row23 col0" >57</td>
#       <td id="T_de7ae_row23_col1" class="data row23 col1" >46</td>
#       <td id="T_de7ae_row23_col2" class="data row23 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_de7ae_row24_col0" class="data row24 col0" >64</td>
#       <td id="T_de7ae_row24_col1" class="data row24 col1" >57</td>
#       <td id="T_de7ae_row24_col2" class="data row24 col2" >53</td>
#     </tr>
#     <tr>
#       <th id="T_de7ae_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_de7ae_row25_col0" class="data row25 col0" >88</td

# %% [markdown]
# #### 最小数据高亮

# %%
df10.style.highlight_min(color = 'yellow')
# Out:
# <style type="text/css">
# #T_0976d_row0_col1, #T_0976d_row1_col5, #T_0976d_row3_col1, #T_0976d_row3_col5, #T_0976d_row4_col1, #T_0976d_row4_col4, #T_0976d_row6_col1, #T_0976d_row6_col5, #T_0976d_row7_col3, #T_0976d_row7_col5, #T_0976d_row8_col1, #T_0976d_row9_col5, #T_0976d_row10_col6, #T_0976d_row11_col5, #T_0976d_row13_col1, #T_0976d_row14_col1, #T_0976d_row15_col1, #T_0976d_row15_col5, #T_0976d_row16_col1, #T_0976d_row16_col5, #T_0976d_row17_col1, #T_0976d_row17_col5, #T_0976d_row18_col1, #T_0976d_row18_col5, #T_0976d_row19_col2, #T_0976d_row20_col0, #T_0976d_row20_col1, #T_0976d_row21_col1, #T_0976d_row21_col5, #T_0976d_row22_col1, #T_0976d_row22_col5, #T_0976d_row23_col1, #T_0976d_row26_col6, #T_0976d_row27_col5, #T_0976d_row28_col1, #T_0976d_row29_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_0976d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0976d_level0_col0" class="col_heading level0 col0" >姓名</th>
#       <th id="T_0976d_level0_col1" class="col_heading level0 col1" >性别</th>
#       <th id="T_0976d_level0_col2" class="col_heading level0 col2" >语文</th>
#       <th id="T_0976d_level0_col3" class="col_heading level0 col3" >数学</th>
#       <th id="T_0976d_level0_col4" class="col_heading level0 col4" >英语</th>
#       <th id="T_0976d_level0_col5" class="col_heading level0 col5" >省份/市</th>
#       <th id="T_0976d_level0_col6" class="col_heading level0 col6" >城市</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0976d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0976d_row0_col0" class="data row0 col0" >彭芸</td>
#       <td id="T_0976d_row0_col1" class="data row0 col1" >女</td>
#       <td id="T_0976d_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_0976d_row0_col3" class="data row0 col3" >43</td>
#       <td id="T_0976d_row0_col4" class="data row0 col4" >49</td>
#       <td id="T_0976d_row0_col5" class="data row0 col5" >安徽</td>
#       <td id="T_0976d_row0_col6" class="data row0 col6" >芜湖</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0976d_row1_col0" class="data row1 col0" >薛加娟</td>
#       <td id="T_0976d_row1_col1" class="data row1 col1" >男</td>
#       <td id="T_0976d_row1_col2" class="data row1 col2" >81</td>
#       <td id="T_0976d_row1_col3" class="data row1 col3" >77</td>
#       <td id="T_0976d_row1_col4" class="data row1 col4" >70</td>
#       <td id="T_0976d_row1_col5" class="data row1 col5" >上海</td>
#       <td id="T_0976d_row1_col6" class="data row1 col6" >浦东</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0976d_row2_col0" class="data row2 col0" >萧忠峰</td>
#       <td id="T_0976d_row2_col1" class="data row2 col1" >男</td>
#       <td id="T_0976d_row2_col2" class="data row2 col2" >45</td>
#       <td id="T_0976d_row2_col3" class="data row2 col3" >43</td>
#       <td id="T_0976d_row2_col4" class="data row2 col4" >79</td>
#       <td id="T_0976d_row2_col5" class="data row2 col5" >安徽</td>
#       <td id="T_0976d_row2_col6" class="data row2 col6" >芜湖</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0976d_row3_col0" class="data row3 col0" >国礼涛</td>
#       <td id="T_0976d_row3_col1" class="data row3 col1" >女</td>
#       <td id="T_0976d_row3_col2" class="data row3 col2" >65</td>
#       <td id="T_0976d_row3_col3" class="data row3 col3" >45</td>
#       <td id="T_0976d_row3_col4" class="data row3 col4" >46</td>
#       <td id="T_0976d_row3_col5" class="data row3 col5" >上海</td>
#       <td id="T_0976d_row3_col6" class="data row3 col6" >浦东</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0976d_row4_col0" class="data row4 col0" >乔忠之</td>
#       <td id="T_0976d_row4_col1" class="data row4 col1" >女</td>
#       <td id="T_0976d_row4_col2" class="data row4 col2" >55</td>
#       <td id="T_0976d_row4_col3" class="data row4 col3" >62</td>
#       <td id="T_0976d_row4_col4" class="data row4 col4" >40</td>
#       <td id="T_0976d_row4_col5" class="data row4 col5" >安徽</td>
#       <td id="T_0976d_row4_col6" class="data row4 col6" >蚌埠</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0976d_row5_col0" class="data row5 col0" >束被永</td>
#       <td id="T_0976d_row5_col1" class="data row5 col1" >男</td>
#       <td id="T_0976d_row5_col2" class="data row5 col2" >45</td>
#       <td id="T_0976d_row5_col3" class="data row5 col3" >50</td>
#       <td id="T_0976d_row5_col4" class="data row5 col4" >97</td>
#       <td id="T_0976d_row5_col5" class="data row5 col5" >安徽</td>
#       <td id="T_0976d_row5_col6" class="data row5 col6" >蚌埠</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0976d_row6_col0" class="data row6 col0" >罗孝翔</td>
#       <td id="T_0976d_row6_col1" class="data row6 col1" >女</td>
#       <td id="T_0976d_row6_col2" class="data row6 col2" >89</td>
#       <td id="T_0976d_row6_col3" class="data row6 col3" >50</td>
#       <td id="T_0976d_row6_col4" class="data row6 col4" >97</td>
#       <td id="T_0976d_row6_col5" class="data row6 col5" >上海</td>
#       <td id="T_0976d_row6_col6" class="data row6 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0976d_row7_col0" class="data row7 col0" >赵秀</td>
#       <td id="T_0976d_row7_col1" class="data row7 col1" >男</td>
#       <td id="T_0976d_row7_col2" class="data row7 col2" >87</td>
#       <td id="T_0976d_row7_col3" class="data row7 col3" >41</td>
#       <td id="T_0976d_row7_col4" class="data row7 col4" >71</td>
#       <td id="T_0976d_row7_col5" class="data row7 col5" >上海</td>
#       <td id="T_0976d_row7_col6" class="data row7 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0976d_row8_col0" class="data row8 col0" >彭姣</td>
#       <td id="T_0976d_row8_col1" class="data row8 col1" >女</td>
#       <td id="T_0976d_row8_col2" class="data row8 col2" >53</td>
#       <td id="T_0976d_row8_col3" class="data row8 col3" >94</td>
#       <td id="T_0976d_row8_col4" class="data row8 col4" >80</td>
#       <td id="T_0976d_row8_col5" class="data row8 col5" >安徽</td>
#       <td id="T_0976d_row8_col6" class="data row8 col6" >滁州</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0976d_row9_col0" class="data row9 col0" >路笑娣</td>
#       <td id="T_0976d_row9_col1" class="data row9 col1" >男</td>
#       <td id="T_0976d_row9_col2" class="data row9 col2" >61</td>
#       <td id="T_0976d_row9_col3" class="data row9 col3" >95</td>
#       <td id="T_0976d_row9_col4" class="data row9 col4" >61</td>
#       <td id="T_0976d_row9_col5" class="data row9 col5" >上海</td>
#       <td id="T_0976d_row9_col6" class="data row9 col6" >闵行</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0976d_row10_col0" class="data row10 col0" >骆贝静</td>
#       <td id="T_0976d_row10_col1" class="data row10 col1" >男</td>
#       <td id="T_0976d_row10_col2" class="data row10 col2" >48</td>
#       <td id="T_0976d_row10_col3" class="data row10 col3" >59</td>
#       <td id="T_0976d_row10_col4" class="data row10 col4" >79</td>
#       <td id="T_0976d_row10_col5" class="data row10 col5" >安徽</td>
#       <td id="T_0976d_row10_col6" class="data row10 col6" >合肥</td>
#     </tr>
#     <tr>
#       <th id="T_0976d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0976d_row11_col0" class="data row11 col0" >劳刚</td>
#       <td id="T_0976d_row11_col1" class="data row11 col1" >男</td>
#       <td id="T_0976d_row11_col2" class="data row11 col2" >82</td>
#       <td id="T_0976d_row11_col3" class="data row11 col3" >94</td>
#       <td id="T_0976d_row11_col4" class="data row11 col4" >90</td>
#       <td id="T_0976d_row11_col5" class="data row11 col5" >上海</td>

# %% [markdown]
# #### 85分以上显示红色

# %%
def color_negative_red(val):
    color = 'red' if val > 85.0 else 'white'
    return 'color: %s' % color
df11.style.applymap(color_negative_red)
# Out:
# <style type="text/css">
# #T_34008_row0_col0, #T_34008_row5_col2, #T_34008_row6_col0, #T_34008_row6_col2, #T_34008_row7_col0, #T_34008_row8_col1, #T_34008_row9_col1, #T_34008_row11_col1, #T_34008_row11_col2, #T_34008_row14_col2, #T_34008_row17_col0, #T_34008_row21_col1, #T_34008_row21_col2, #T_34008_row22_col0, #T_34008_row25_col0, #T_34008_row27_col1, #T_34008_row29_col2 {
#   color: red;
# }
# #T_34008_row0_col1, #T_34008_row0_col2, #T_34008_row1_col0, #T_34008_row1_col1, #T_34008_row1_col2, #T_34008_row2_col0, #T_34008_row2_col1, #T_34008_row2_col2, #T_34008_row3_col0, #T_34008_row3_col1, #T_34008_row3_col2, #T_34008_row4_col0, #T_34008_row4_col1, #T_34008_row4_col2, #T_34008_row5_col0, #T_34008_row5_col1, #T_34008_row6_col1, #T_34008_row7_col1, #T_34008_row7_col2, #T_34008_row8_col0, #T_34008_row8_col2, #T_34008_row9_col0, #T_34008_row9_col2, #T_34008_row10_col0, #T_34008_row10_col1, #T_34008_row10_col2, #T_34008_row11_col0, #T_34008_row12_col0, #T_34008_row12_col1, #T_34008_row12_col2, #T_34008_row13_col0, #T_34008_row13_col1, #T_34008_row13_col2, #T_34008_row14_col0, #T_34008_row14_col1, #T_34008_row15_col0, #T_34008_row15_col1, #T_34008_row15_col2, #T_34008_row16_col0, #T_34008_row16_col1, #T_34008_row16_col2, #T_34008_row17_col1, #T_34008_row17_col2, #T_34008_row18_col0, #T_34008_row18_col1, #T_34008_row18_col2, #T_34008_row19_col0, #T_34008_row19_col1, #T_34008_row19_col2, #T_34008_row20_col0, #T_34008_row20_col1, #T_34008_row20_col2, #T_34008_row21_col0, #T_34008_row22_col1, #T_34008_row22_col2, #T_34008_row23_col0, #T_34008_row23_col1, #T_34008_row23_col2, #T_34008_row24_col0, #T_34008_row24_col1, #T_34008_row24_col2, #T_34008_row25_col1, #T_34008_row25_col2, #T_34008_row26_col0, #T_34008_row26_col1, #T_34008_row26_col2, #T_34008_row27_col0, #T_34008_row27_col2, #T_34008_row28_col0, #T_34008_row28_col1, #T_34008_row28_col2, #T_34008_row29_col0, #T_34008_row29_col1 {
#   color: white;
# }
# </style>
# <table id="T_34008">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34008_level0_col0" class="col_heading level0 col0" >语文</th>
#       <th id="T_34008_level0_col1" class="col_heading level0 col1" >数学</th>
#       <th id="T_34008_level0_col2" class="col_heading level0 col2" >英语</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34008_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34008_row0_col0" class="data row0 col0" >88</td>
#       <td id="T_34008_row0_col1" class="data row0 col1" >43</td>
#       <td id="T_34008_row0_col2" class="data row0 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34008_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_34008_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_34008_row1_col2" class="data row1 col2" >70</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34008_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_34008_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_34008_row2_col2" class="data row2 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34008_row3_col0" class="data row3 col0" >65</td>
#       <td id="T_34008_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_34008_row3_col2" class="data row3 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34008_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_34008_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_34008_row4_col2" class="data row4 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34008_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_34008_row5_col1" class="data row5 col1" >50</td>
#       <td id="T_34008_row5_col2" class="data row5 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34008_row6_col0" class="data row6 col0" >89</td>
#       <td id="T_34008_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_34008_row6_col2" class="data row6 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34008_row7_col0" class="data row7 col0" >87</td>
#       <td id="T_34008_row7_col1" class="data row7 col1" >41</td>
#       <td id="T_34008_row7_col2" class="data row7 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34008_row8_col0" class="data row8 col0" >53</td>
#       <td id="T_34008_row8_col1" class="data row8 col1" >94</td>
#       <td id="T_34008_row8_col2" class="data row8 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34008_row9_col0" class="data row9 col0" >61</td>
#       <td id="T_34008_row9_col1" class="data row9 col1" >95</td>
#       <td id="T_34008_row9_col2" class="data row9 col2" >61</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_34008_row10_col0" class="data row10 col0" >48</td>
#       <td id="T_34008_row10_col1" class="data row10 col1" >59</td>
#       <td id="T_34008_row10_col2" class="data row10 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_34008_row11_col0" class="data row11 col0" >82</td>
#       <td id="T_34008_row11_col1" class="data row11 col1" >94</td>
#       <td id="T_34008_row11_col2" class="data row11 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_34008_row12_col0" class="data row12 col0" >79</td>
#       <td id="T_34008_row12_col1" class="data row12 col1" >53</td>
#       <td id="T_34008_row12_col2" class="data row12 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_34008_row13_col0" class="data row13 col0" >76</td>
#       <td id="T_34008_row13_col1" class="data row13 col1" >50</td>
#       <td id="T_34008_row13_col2" class="data row13 col2" >47</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_34008_row14_col0" class="data row14 col0" >49</td>
#       <td id="T_34008_row14_col1" class="data row14 col1" >43</td>
#       <td id="T_34008_row14_col2" class="data row14 col2" >91</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_34008_row15_col0" class="data row15 col0" >41</td>
#       <td id="T_34008_row15_col1" class="data row15 col1" >71</td>
#       <td id="T_34008_row15_col2" class="data row15 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_34008_row16_col0" class="data row16 col0" >42</td>
#       <td id="T_34008_row16_col1" class="data row16 col1" >67</td>
#       <td id="T_34008_row16_col2" class="data row16 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_34008_row17_col0" class="data row17 col0" >93</td>
#       <td id="T_34008_row17_col1" class="data row17 col1" >54</td>
#       <td id="T_34008_row17_col2" class="data row17 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_34008_row18_col0" class="data row18 col0" >63</td>
#       <td id="T_34008_row18_col1" class="data row18 col1" >49</td>
#       <td id="T_34008_row18_col2" class="data row18 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_34008_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_34008_row19_col0" class="data row19 col0" >40</td>

# %% [markdown]
# #### 上面两个功能混合

# %%
df11.style.applymap(color_negative_red).apply(highlight_max)
# Out:
# <style type="text/css">
# #T_b304b_row0_col0, #T_b304b_row6_col0, #T_b304b_row7_col0, #T_b304b_row8_col1, #T_b304b_row11_col1, #T_b304b_row11_col2, #T_b304b_row14_col2, #T_b304b_row21_col1, #T_b304b_row21_col2, #T_b304b_row22_col0, #T_b304b_row25_col0, #T_b304b_row27_col1, #T_b304b_row29_col2 {
#   color: red;
# }
# #T_b304b_row0_col1, #T_b304b_row0_col2, #T_b304b_row1_col0, #T_b304b_row1_col1, #T_b304b_row1_col2, #T_b304b_row2_col0, #T_b304b_row2_col1, #T_b304b_row2_col2, #T_b304b_row3_col0, #T_b304b_row3_col1, #T_b304b_row3_col2, #T_b304b_row4_col0, #T_b304b_row4_col1, #T_b304b_row4_col2, #T_b304b_row5_col0, #T_b304b_row5_col1, #T_b304b_row6_col1, #T_b304b_row7_col1, #T_b304b_row7_col2, #T_b304b_row8_col0, #T_b304b_row8_col2, #T_b304b_row9_col0, #T_b304b_row9_col2, #T_b304b_row10_col0, #T_b304b_row10_col1, #T_b304b_row10_col2, #T_b304b_row11_col0, #T_b304b_row12_col0, #T_b304b_row12_col1, #T_b304b_row12_col2, #T_b304b_row13_col0, #T_b304b_row13_col1, #T_b304b_row13_col2, #T_b304b_row14_col0, #T_b304b_row14_col1, #T_b304b_row15_col0, #T_b304b_row15_col1, #T_b304b_row15_col2, #T_b304b_row16_col0, #T_b304b_row16_col1, #T_b304b_row16_col2, #T_b304b_row17_col1, #T_b304b_row17_col2, #T_b304b_row18_col0, #T_b304b_row18_col1, #T_b304b_row18_col2, #T_b304b_row19_col0, #T_b304b_row19_col1, #T_b304b_row19_col2, #T_b304b_row20_col0, #T_b304b_row20_col1, #T_b304b_row20_col2, #T_b304b_row21_col0, #T_b304b_row22_col1, #T_b304b_row22_col2, #T_b304b_row23_col0, #T_b304b_row23_col1, #T_b304b_row23_col2, #T_b304b_row24_col0, #T_b304b_row24_col1, #T_b304b_row24_col2, #T_b304b_row25_col1, #T_b304b_row25_col2, #T_b304b_row26_col0, #T_b304b_row26_col1, #T_b304b_row26_col2, #T_b304b_row27_col0, #T_b304b_row27_col2, #T_b304b_row28_col0, #T_b304b_row28_col1, #T_b304b_row28_col2, #T_b304b_row29_col0, #T_b304b_row29_col1 {
#   color: white;
# }
# #T_b304b_row5_col2, #T_b304b_row6_col2, #T_b304b_row9_col1, #T_b304b_row17_col0 {
#   color: red;
#   background-color: yellow;
# }
# </style>
# <table id="T_b304b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b304b_level0_col0" class="col_heading level0 col0" >语文</th>
#       <th id="T_b304b_level0_col1" class="col_heading level0 col1" >数学</th>
#       <th id="T_b304b_level0_col2" class="col_heading level0 col2" >英语</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b304b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b304b_row0_col0" class="data row0 col0" >88</td>
#       <td id="T_b304b_row0_col1" class="data row0 col1" >43</td>
#       <td id="T_b304b_row0_col2" class="data row0 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b304b_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_b304b_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_b304b_row1_col2" class="data row1 col2" >70</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b304b_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_b304b_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_b304b_row2_col2" class="data row2 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b304b_row3_col0" class="data row3 col0" >65</td>
#       <td id="T_b304b_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_b304b_row3_col2" class="data row3 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b304b_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_b304b_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_b304b_row4_col2" class="data row4 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b304b_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_b304b_row5_col1" class="data row5 col1" >50</td>
#       <td id="T_b304b_row5_col2" class="data row5 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b304b_row6_col0" class="data row6 col0" >89</td>
#       <td id="T_b304b_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_b304b_row6_col2" class="data row6 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b304b_row7_col0" class="data row7 col0" >87</td>
#       <td id="T_b304b_row7_col1" class="data row7 col1" >41</td>
#       <td id="T_b304b_row7_col2" class="data row7 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b304b_row8_col0" class="data row8 col0" >53</td>
#       <td id="T_b304b_row8_col1" class="data row8 col1" >94</td>
#       <td id="T_b304b_row8_col2" class="data row8 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b304b_row9_col0" class="data row9 col0" >61</td>
#       <td id="T_b304b_row9_col1" class="data row9 col1" >95</td>
#       <td id="T_b304b_row9_col2" class="data row9 col2" >61</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b304b_row10_col0" class="data row10 col0" >48</td>
#       <td id="T_b304b_row10_col1" class="data row10 col1" >59</td>
#       <td id="T_b304b_row10_col2" class="data row10 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b304b_row11_col0" class="data row11 col0" >82</td>
#       <td id="T_b304b_row11_col1" class="data row11 col1" >94</td>
#       <td id="T_b304b_row11_col2" class="data row11 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b304b_row12_col0" class="data row12 col0" >79</td>
#       <td id="T_b304b_row12_col1" class="data row12 col1" >53</td>
#       <td id="T_b304b_row12_col2" class="data row12 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b304b_row13_col0" class="data row13 col0" >76</td>
#       <td id="T_b304b_row13_col1" class="data row13 col1" >50</td>
#       <td id="T_b304b_row13_col2" class="data row13 col2" >47</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b304b_row14_col0" class="data row14 col0" >49</td>
#       <td id="T_b304b_row14_col1" class="data row14 col1" >43</td>
#       <td id="T_b304b_row14_col2" class="data row14 col2" >91</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b304b_row15_col0" class="data row15 col0" >41</td>
#       <td id="T_b304b_row15_col1" class="data row15 col1" >71</td>
#       <td id="T_b304b_row15_col2" class="data row15 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b304b_row16_col0" class="data row16 col0" >42</td>
#       <td id="T_b304b_row16_col1" class="data row16 col1" >67</td>
#       <td id="T_b304b_row16_col2" class="data row16 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b304b_row17_col0" class="data row17 col0" >93</td>
#       <td id="T_b304b_row17_col1" class="data row17 col1" >54</td>
#       <td id="T_b304b_row17_col2" class="data row17 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b304b_row18_col0" class="data row18 col0" >63</td>
#       <td id="T_b304b_row18_col1" class="data row18 col1" >49</td>
#       <td id="T_b304b_row18_col2" class="data row18 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_b304b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b304b_ro

# %% [markdown]
# #### 显示热度图

# %%
# 9.13 显示热度图
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)
df11.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_fd1b7_row0_col0, #T_fd1b7_row25_col0 {
#   background-color: #168b16;
#   color: #f1f1f1;
# }
# #T_fd1b7_row0_col1, #T_fd1b7_row2_col1, #T_fd1b7_row14_col1, #T_fd1b7_row16_col0, #T_fd1b7_row21_col0 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_fd1b7_row0_col2 {
#   background-color: #c6e1c6;
#   color: #000000;
# }
# #T_fd1b7_row1_col0 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_fd1b7_row1_col1, #T_fd1b7_row26_col1 {
#   background-color: #4ea64e;
#   color: #f1f1f1;
# }
# #T_fd1b7_row1_col2 {
#   background-color: #6fb76f;
#   color: #f1f1f1;
# }
# #T_fd1b7_row2_col0, #T_fd1b7_row5_col0 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_fd1b7_row2_col2, #T_fd1b7_row10_col2 {
#   background-color: #4aa44a;
#   color: #f1f1f1;
# }
# #T_fd1b7_row3_col0 {
#   background-color: #7cbd7c;
#   color: #000000;
# }
# #T_fd1b7_row3_col1 {
#   background-color: #daebda;
#   color: #000000;
# }
# #T_fd1b7_row3_col2 {
#   background-color: #d3e7d3;
#   color: #000000;
# }
# #T_fd1b7_row4_col0 {
#   background-color: #a8d2a8;
#   color: #000000;
# }
# #T_fd1b7_row4_col1, #T_fd1b7_row29_col1 {
#   background-color: #8fc68f;
#   color: #000000;
# }
# #T_fd1b7_row4_col2, #T_fd1b7_row7_col1, #T_fd1b7_row19_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_fd1b7_row5_col1, #T_fd1b7_row6_col1, #T_fd1b7_row13_col1 {
#   background-color: #c4e0c4;
#   color: #000000;
# }
# #T_fd1b7_row5_col2, #T_fd1b7_row6_col2, #T_fd1b7_row9_col1, #T_fd1b7_row17_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_fd1b7_row6_col0, #T_fd1b7_row22_col0 {
#   background-color: #118911;
#   color: #f1f1f1;
# }
# #T_fd1b7_row7_col0 {
#   background-color: #1a8d1a;
#   color: #f1f1f1;
# }
# #T_fd1b7_row7_col2 {
#   background-color: #6bb46b;
#   color: #f1f1f1;
# }
# #T_fd1b7_row8_col0 {
#   background-color: #b2d7b1;
#   color: #000000;
# }
# #T_fd1b7_row8_col1, #T_fd1b7_row11_col1 {
#   background-color: #048204;
#   color: #f1f1f1;
# }
# #T_fd1b7_row8_col2, #T_fd1b7_row19_col2, #T_fd1b7_row22_col2 {
#   background-color: #46a246;
#   color: #f1f1f1;
# }
# #T_fd1b7_row9_col0 {
#   background-color: #8ec58e;
#   color: #000000;
# }
# #T_fd1b7_row9_col2 {
#   background-color: #94c994;
#   color: #000000;
# }
# #T_fd1b7_row10_col0 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_fd1b7_row10_col1 {
#   background-color: #9ccd9c;
#   color: #000000;
# }
# #T_fd1b7_row11_col0, #T_fd1b7_row26_col0 {
#   background-color: #319831;
#   color: #f1f1f1;
# }
# #T_fd1b7_row11_col2, #T_fd1b7_row29_col2 {
#   background-color: #1d8e1d;
#   color: #f1f1f1;
# }
# #T_fd1b7_row12_col0 {
#   background-color: #3e9e3e;
#   color: #f1f1f1;
# }
# #T_fd1b7_row12_col1 {
#   background-color: #b7dab7;
#   color: #000000;
# }
# #T_fd1b7_row12_col2 {
#   background-color: #a1cfa1;
#   color: #000000;
# }
# #T_fd1b7_row13_col0 {
#   background-color: #4ba54b;
#   color: #f1f1f1;
# }
# #T_fd1b7_row13_col2 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_fd1b7_row14_col0 {
#   background-color: #c3e0c3;
#   color: #000000;
# }
# #T_fd1b7_row14_col2 {
#   background-color: #188c18;
#   color: #f1f1f1;
# }
# #T_fd1b7_row15_col0 {
#   background-color: #e7f1e7;
#   color: #000000;
# }
# #T_fd1b7_row15_col1 {
#   background-color: #68b368;
#   color: #f1f1f1;
# }
# #T_fd1b7_row15_col2 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_fd1b7_row16_col1 {
#   background-color: #79bc79;
#   color: #000000;
# }
# #T_fd1b7_row16_col2 {
#   background-color: #359a35;
#   color: #f1f1f1;
# }
# #T_fd1b7_row17_col1 {
#   background-color: #b2d7b2;
#   color: #000000;
# }
# #T_fd1b7_row17_col2, #T_fd1b7_row23_col2 {
#   background-color: #add5ad;
#   color: #000000;
# }
# #T_fd1b7_row18_col0 {
#   background-color: #84c184;
#   color: #000000;
# }
# #T_fd1b7_row18_col1 {
#   background-color: #c9e2c8;
#   color: #000000;
# }
# #T_fd1b7_row18_col2 {
#   background-color: #84c084;
#   color: #000000;
# }
# #T_fd1b7_row19_col1 {
#   background-color: #389b38;
#   color: #f1f1f1;
# }
# #T_fd1b7_row20_col0, #T_fd1b7_row28_col0 {
#   background-color: #beddbe;
#   color: #000000;
# }
# #T_fd1b7_row20_col1, #T_fd1b7_row23_col1, #T_fd1b7_row28_col1 {
#   background-color: #d5e9d5;
#   color: #000000;
# }
# #T_fd1b7_row20_col2, #T_fd1b7_row29_col0 {
#   background-color: #73b873;
#   color: #f1f1f1;
# }
# #T_fd1b7_row21_col1 {
#   background-color: #118811;
#   color: #f1f1f1;
# }
# #T_fd1b7_row21_col2 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_fd1b7_row22_col1 {
#   background-color: #309730;
#   color: #f1f1f1;
# }
# #T_fd1b7_row23_col0 {
#   background-color: #9fce9f;
#   color: #000000;
# }
# #T_fd1b7_row24_col0 {
#   background-color: #81bf81;
#   color: #000000;
# }
# #T_fd1b7_row24_col1 {
#   background-color: #a6d1a6;
#   color: #000000;
# }
# #T_fd1b7_row24_col2 {
#   background-color: #b5d9b5;
#   color: #000000;
# }
# #T_fd1b7_row25_col1 {
#   background-color: #6db56d;
#   color: #f1f1f1;
# }
# #T_fd1b7_row25_col2 {
#   background-color: #d6e9d6;
#   color: #000000;
# }
# #T_fd1b7_row26_col2 {
#   background-color: #bdddbd;
#   color: #000000;
# }
# #T_fd1b7_row27_col0 {
#   background-color: #42a042;
#   color: #f1f1f1;
# }
# #T_fd1b7_row27_col1 {
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_fd1b7_row27_col2 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_fd1b7_row28_col2 {
#   background-color: #78bb78;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fd1b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd1b7_level0_col0" class="col_heading level0 col0" >语文</th>
#       <th id="T_fd1b7_level0_col1" class="col_heading level0 col1" >数学</th>
#       <th id="T_fd1b7_level0_col2" class="col_heading level0 col2" >英语</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd1b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd1b7_row0_col0" class="data row0 col0" >88</td>
#       <td id="T_fd1b7_row0_col1" class="data row0 col1" >43</td>
#       <td id="T_fd1b7_row0_col2" class="data row0 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd1b7_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_fd1b7_row1_col1" class="data row1 col1" >77</td>
#       <td id="T_fd1b7_row1_col2" class="data row1 col2" >70</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd1b7_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_fd1b7_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_fd1b7_row2_col2" class="data row2 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd1b7_row3_col0" class="data row3 col0" >65</td>
#       <td id="T_fd1b7_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_fd1b7_row3_col2" class="data row3 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd1b7_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_fd1b7_row4_col1" class="data row4 col1" >62</td>
#       <td id="T_fd1b7_row4_col2" class="data row4 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd1b7_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_fd1b7_row5_col1" class="data row5 col1" >50</td>
#       <td id="T_fd1b7_row5_col2" class="data row5 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd1b7_row6_col0" class="data row6 col0" >89</td>
#       <td id="T_fd1b7_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_fd1b7_row6_col2" class="data row6 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd1b7_row7_col0" class="data row7 col0" >87</td>
#       <td id="T_fd1b7_row7_col1" class="data row7 col1" >41</td>
#       <td id="T_fd1b7_row7_col2" class="data row7 col2" >71</td>
#     </tr>
#     <tr>
#       <th id="T_fd1b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd1b7_row8_col0" class="data row8 col0" >53</td>
#       <td id="T_fd1b7_row8_col1" class="data row8 col1" >94</td>
#       <td id="T_fd1b7_row8_col2" class="data row8 col2" >80</td>
#     </tr>
#     <tr>
